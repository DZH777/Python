# %% [markdown]
# ### Python module/package imports for this chapter

# %%
import math, json, collections, itertools

# %%
import numpy as np
import matplotlib.pyplot as pp
# %matplotlib inline

# %%
from mpl_toolkits.basemap import Basemap
import geopy

# %% [markdown]
# ### Code and data needed from previous videos

# %%
medal = collections.namedtuple('medal',['year','athlete','team','event'])
medals = [medal(*line.strip().split('\t')) for line in open('goldmedals.txt','r')]

# %% [markdown]
# ## Refactoring code to make it Pythonic

# %%
import this
# Out:
# The Zen of Python, by Tim Peters
#
# Beautiful is better than ugly.
# Explicit is better than implicit.
# Simple is better than complex.
# Complex is better than complicated.
# Flat is better than nested.
# Sparse is better than dense.
# Readability counts.
# Special cases aren't special enough to break the rules.
# Although practicality beats purity.
# Errors should never pass silently.
# Unless explicitly silenced.
# In the face of ambiguity, refuse the temptation to guess.
# There should be one-- and preferably only one --obvious way to do it.
# Although that way may not be obvious at first unless you're Dutch.
# Now is better than never.
# Although never is often better than *right* now.
# If the implementation is hard to explain, it's a bad idea.
# If the implementation is easy to explain, it may be a good idea.
# Namespaces are one honking great idea -- let's do more of those!

# %%
athletes = []

for medal in medals:
    if medal.athlete not in athletes:
        athletes.append(medal.athlete)
athletes.sort()

print(len(athletes))
# Out:
# 999

# %%
athletes[:]
# Out:
# ['Abdon Pamich',
#  'Abebe Bikila',
#  'Abel Kiviat',
#  'Adhemar Ferreira Da Silva',
#  'Adolfo Consolini',
#  'Aksana Miankova',
#  'Alain Mimoun',
#  'Alan Helffrich',
#  'Albert Hill',
#  'Albert Lovejoy Gutterson',
#  'Alberto Cova',
#  'Alberto Juantorena',
#  'Albin Oskar Stenroos',
#  'Aleen Bailey',
#  'Aleksandr Aksinin',
#  'Aleksandra Fedoriva',
#  'Alessandro Andrei',
#  'Alex Schwazer',
#  'Alfred Carleten Gilbert',
#  'Alfred Oerter',
#  'Alfred Tysoe',
#  'Alfredrick Alphonzo Joyner',
#  'Alice Marie Coachman',
#  'Alice Regina Brown',
#  'Alistair Brownlee',
#  'Allan Wells',
#  'Allen Johnson',
#  'Allen Woodring',
#  'Allyson Felix',
#  'Alma Wilfred Richards',
#  'Almaz Ayana',
#  'Alonzo C. Babers',
#  'Alptekin Asli Cakir',
#  'Alvin Harrison',
#  'Alvin Kraenzlein',
#  'Amos Kipwabok Biwott',
#  'Anatoli Bondarchuk',
#  'Anders Garderud',
#  'Andre Lamar Phillips',
#  'Andrea Anderson',
#  'Andreas Thorkildsen',
#  'Andrei Prokofiev',
#  'Andrew Valmon',
#  'Andrew William Stanfield',
#  'Andrey Abduvaliev',
#  'Andrey Perlov',
#  'Andrey Silnov',
#  'Angela Nemeth-Ranky',
#  'Angela Voigt',
#  'Angelo Taylor',
#  'Anier Garcia',
#  'Anisoara Cusmir-Stanciu',
#  'Anita Wlodarczyk',
#  'Ann Elizabeth Packer',
#  'Anna Chicherova',
#  'Annegret Richter-Irrgang',
#  'Annelie Ehrhardt',
#  'Annette Joan Rogers',
#  'Anthony William Winter',
#  'Anthuan Maybank',
#  'Antonio Ricardo Mckay',
#  'Archibald Franklin Williams',
#  'Archie Hahn',
#  'Ariana Washington',
#  'Aries Merritt',
#  'Arlie Alfred Schardt',
#  'Arman Hall',
#  'Armas Rudolf Taipale',
#  'Armin Hary',
#  'Arne Ahman',
#  'Arnie Robinson',
#  'Arnold Jackson',
#  'Arsi Harju',
#  'Arthur Godfrey Kilner Brown',
#  'Arthur Harold Harnden',
#  'Arthur James Robertson',
#  'Arthur Newton',
#  'Arthur Russell',
#  'Arthur Wint',
#  'Arto Harkonen',
#  'Asafa Powell',
#  'Asbel Kipruto Kiprop',
#  'Ashton Eaton',
#  'Astrid Kumbernuss',
#  'Athanasia Tsoumeleka',
#  'Balazs Kiss',
#  'Barbara Ann Ferrell',
#  'Barbara Pearl Jones',
#  'Barbora Spotakova',
#  'Benita Fitzgerald-Brown',
#  'Benjamin Gene Brown',
#  'Bernard Williams iii',
#  'Bernd Cullmann',
#  'Bernd Kannenberg',
#  'Betty Cuthbert',
#  'Beverly Mcdonald',
#  "Bevil Gordon D'Urban Rudd",
#  'Bianca Knight',
#  'Bob Beamon',
#  'Boughera Mohamed El Ouafi',
#  'Brian Lewis',
#  'Brianna Rollins',
#  'Brigitte Rohde',
#  'Brimin Kiprop Kipruto',
#  'Brittney Reese',
#  'Bronislaw Malinowski',
#  'Bruny Surin',
#  'Bryan Clay',
#  'BГ¤rbel Eckert-WГ¶ckel',
#  'Calvin Smith',
#  'Carl Lewis',
#  'Carla Bodendorf',
#  'Carlette D. Guidry-White',
#  'Carlos Lopes',
#  'Carlton Chambers',
#  'Carmelita Jeter',
#  'Carolina Kluft',
#  'Caster Semenya',
#  'Caterine Ibarguen',
#  'Catherine Hardy',
#  'Cathy Freeman',
#  'Cecil Richmond Griffiths',
#  'Chandra Danette Cheeseborough',
#  'Chandra Sturrup',
#  'Charles Asati',
#  'Charles Austin',
#  'Charles Bennett',
#  'Charles Decker Reidpath',
#  'Charles Dvorak',
#  'Charles Edward Borah',
#  'Charles Edward Greene',
#  'Charles Everett Dumas',
#  'Charles Hewes Jr. Moore',
#  'Charles Joseph Bacon',
#  'Charles L. Jenkins',
#  'Charles Lamont Jenkins',
#  'Charles Paddock',
#  'Chioma Ajunwa',
#  'Chris Brown',
#  'Christian Olsson',
#  'Christian Schenk',
#  'Christian Taylor',
#  'Christiane Krause',
#  'Christina Brehmer-Lathan',
#  'Christine Ohuruogu',
#  'Christoph Harting',
#  'Christoph HГ¶hne',
#  'Christopher William Brasher',
#  'Chryste Gaines',
#  'Chuhei Nambu',
#  'Claudia Losch',
#  'Clifford Frederick Bourland',
#  'Colette Besson',
#  'Commodore Cochrane',
#  'Conseslus Kipruto',
#  'Constantina Tomescu',
#  'Cornelius Cooper Johnson',
#  'Courtney Okolo',
#  'Crystal Cox',
#  'Cyrus C. Jr. Young',
#  'Dagmar KГ¤sling',
#  'Dainis Kula',
#  'Daley Thompson',
#  'Dalilah Muhammad',
#  'Dallas Crutcher III Long',
#  "Dan O'brien",
#  'Dana Ingrova-Zatopkova',
#  'Daniel Bautista rocha',
#  'Daniel Everett',
#  'Daniel Kinsey',
#  'Daniel Plaza montero',
#  'Darnell Hall',
#  'Darold Williamson',
#  'Darren Campbell',
#  'David Curtis Munson',
#  'David George Burghley',
#  'David Henry Jacobs',
#  'David James Wottle',
#  'David Lekuta Rudisha',
#  'David Neville',
#  'David Peter Hemery',
#  'David Verburg',
#  'Dawn Harper',
#  'Dayron Robles',
#  'Debbie Ferguson-Mckenzie',
#  'Deborah Flintoff-King',
#  'DeeDee Trotter',
#  'Deedee Trotter',
#  'Delfo Cabrera',
#  'Demetrius Pinder',
#  'Denise Lewis',
#  'Dennis Mitchell',
#  'Deon Marie Hemmings',
#  'Derartu Tulu',
#  'Derek Drouin',
#  'Derek Mills',
#  'Derrick Adkins',
#  'Derrick Brew',
#  'Diamond Dixon',
#  'Dieter Baumann',
#  'Dietmar MГ¶genburg',
#  'Dilshod Nazarov',
#  'Ding Chen',
#  'Doina Besliu-Melinte',
#  'Donald George Bragg',
#  'Donald James Thompson',
#  'Donald Quarrie',
#  'Donovan Bailey',
#  'Doris Maletzki',
#  'Dorothy Louise Ritter',
#  'Douglas Gordon Lowe',
#  'Duncan Mcnaughton',
#  'Dwight Phillips',
#  'Earl Thomson',
#  'Earl Verdelle Young',
#  'Earle Elmer Meadows',
#  'Eddie Tolan',
#  'Edgar Allen Ablowich',
#  'Edith Marie Mcguire',
#  'Edward Barton Hamm',
#  'Edward F. Lindberg',
#  'Edward James Hart',
#  'Edward Lansing Gordon',
#  'Edward Tiffin Cooke',
#  'Edwin Flack',
#  'Edwin Moses',
#  'Eero Berg',
#  'Eero Reino Lehtonen',
#  'Egil Danielsen',
#  'Eino Rastas',
#  'Eino SeppГ¤lГ¤',
#  'Ekaterini Stefanidi',
#  'Elaine Thompson',
#  'Eldice Lewis',
#  'Elena Isinbaeva',
#  'Elena Lashmanova',
#  'Elena Romanova',
#  'Elena Slesarenko',
#  'Elias Katz',
#  'Eliud Kipchoge',
#  'Elizabeth Robinson',
#  'Ellen Stropahl-Streidt',
#  'Ellen Van langen',
#  'Ellery Clark',
#  'Ellina Zvereva',
#  'Elmer Konstantin Niklander',
#  'Elvira Ozolina',
#  'Elzbieta Dunska-Krzesinska',
#  'Emerson Lane Spencer',
#  'Emil Robert Voigt',
#  'Emil Zatopek',
#  'English Gardner',
#  'Eric Henry Liddell',
#  'Eric Lemming',
#  'Eric Randolph Barnes',
#  'Erik H. Lundqvist',
#  'Erki Nool',
#  'Ernesto Canto gudino',
#  'Esther Cornelia Brand',
#  'Esther Jones',
#  'Ethel Catherwood',
#  'Ethel M. Smith',
#  'Etienne Desmarteau',
#  'Evelin Schlaak-Jahl',
#  'Evelyn Ashford',
#  'Evelyn Furtsch',
#  'Evgeniya Polyakova',
#  'Ewa Klobukowska',
#  'Ezekiel Kemboi',
#  'Faina Melnik',
#  'Faith Chepngetich Kipyegon',
#  'Fani Chalkia',
#  'Fanny Blankers-Koen',
#  'Fanny Rosenfeld',
#  'Fatuma Roba',
#  'Felix Sanchez',
#  'Ferdinand Reinhardt Bie',
#  'Fermin Cacho ruiz',
#  'Fernanda Ribeiro',
#  'Finis Dean Smith',
#  'Florence Griffith-Joyner',
#  'Fluer Northey Mellor-Wenham',
#  'Forrest Grady Towns',
#  'Forrest Smithson',
#  'Foy Draper',
#  'Francena McCorory',
#  'Francena Mccorory',
#  'Francis C. Irons',
#  'Francis Hussey',
#  'Francis Jarvis',
#  'Francoise Mbango etone',
#  'Frank Charles Shorter',
#  'Frank Clifford Wykoff',
#  'Frank Foss',
#  'Frank Loomis',
#  'Frans Wilhelmi PГ¶rhГ¶lГ¤',
#  'Frederick Delmont Tootell',
#  'Frederick Ferdinand Wolff',
#  'Frederick Kelly',
#  'Frederick Morgan Hansen',
#  'Frederick Morgan Taylor',
#  'Frederick Pitt Alderman',
#  'Frederick Schule',
#  'Frederick Vaughn Newhouse',
#  'Frederik Teudor Koskenniemi',
#  'Frej Liewendhal',
#  'Gabriela Szabo',
#  'Gabriella Dorio',
#  'Gail Devers',
#  'Galina Zybina',
#  'Gaston Etienne Reiff',
#  'Gaston Roelants',
#  'Gelindo Bordin',
#  'Gennadi Avdeenko',
#  'George Edward Larner',
#  'George Goulding',
#  'George Hetzel Baird',
#  'George J. Jr. Saling',
#  'George Lawrence James',
#  'George Orton',
#  'George Underwood',
#  'George V. Bonhag',
#  'Gerald A. Tinker',
#  'Gerald Howard Ashworth',
#  'Gerd Kanter',
#  'Gerd Wessig',
#  'Gerda Johanna Marie Van der kade-Koudijs',
#  'Gerhard (Gerd) StГ¶ck',
#  'Gezahegne Abera',
#  'Ghada Shouaa',
#  'Gil Roberts',
#  'Gisela Mauermayer',
#  'Giuseppe Dordoni',
#  'Glenn Ashby Davis',
#  'Glenn Edward Morris',
#  'Glenn Foster Hardin',
#  'Glenroy Gilbert',
#  'Glyniss Leanne Nunn-Saunders-Cearns',
#  'Godfrey Lionel Rampling',
#  'Greg Rutherford',
#  'Gregory Curtis Bell',
#  'Gulnara Galkina-Samitova',
#  'Gunnar HГ¶ckert',
#  'Gustav Lindblom',
#  'Guy Drut',
#  'Guy Montagu Butler',
#  'Gwen Jorgensen',
#  'Gwen Torrence',
#  'Gyula Zsivotzky',
#  'Haile Gebrselassie',
#  'Halina Herrmann-Gorecka-Richter',
#  'Halina Konopacka',
#  'Hannes Kolehmainen',
#  'Hans Woellke',
#  'Harold Abrahams',
#  'Harold Marion Osborn',
#  'Harold Norwood Ewell',
#  'Harold Vincent Connolly',
#  'Harri Edvin Larva',
#  'Harriett Claiborne Bland',
#  'Harrison Dillard',
#  'Harry Butch . Reynolds',
#  'Harry Franklin Porter',
#  'Harry Hillman',
#  'Harry Stoddard Babcock',
#  'Hartwig Gauder',
#  'Harvey Edward Glance',
#  'Hasely Crawford',
#  'Hassiba Boulmerka',
#  'Hayes Jones',
#  'Hector Harold Whitlock',
#  'Hector Monroe Dyer',
#  'Heidemarie Rosendahl',
#  'Heike Drechsler',
#  'Heike Henkel',
#  'Heikki Liimatainen',
#  'Helen Herring Stephens',
#  'Helga Seidler',
#  'Helge Andreas LГ¶vland',
#  'Heli Orvokki Rantanen',
#  'Henry Argue Russell',
#  'Henry Carr',
#  'Henry Eriksson',
#  'Henry Louis Scott',
#  'Henry Maitland Mackintosh',
#  'Herbert Elliott',
#  'Herbert Mckenley',
#  'Herman Ronald Frazier',
#  'Hermine (Herma) Bauma',
#  'Hezekiah Munyoro Nyamau',
#  'Hicham El guerrouj',
#  'Hildegard Falck-Janze',
#  'Hjalmar Andersson',
#  'Hong Liu',
#  'Horace Hallock Brown',
#  'Horace III Ashenfelter',
#  'Howard Valentine',
#  'Hugo K. Wieslander',
#  'Huina Xing',
#  'Ibolya Csak',
#  'Ilke Wyludda',
#  'Ilmari Salminen',
#  'Ilona Schoknecht-Slupianek',
#  'Imre Nemeth',
#  'Inese Yaunzeme',
#  'Inessa Kravets',
#  'Inger Miller',
#  'Ingrid Auerswald-Lange',
#  'Ingrid Becker-Mickler',
#  'Iolanda Balas',
#  'Ira James Murchison',
#  'Irena Szewinska',
#  'Irina Nazarova',
#  'Irina Privalova',
#  'Irving Baxter',
#  'Irving Jahir Saladino aranda',
#  'Iryna Press',
#  'Ivan Dresser',
#  'Ivan Pedroso',
#  'Ivan Ukhov',
#  'Ivan William Fuqua',
#  'Ivanka Mikailova Christova-Todorova',
#  'Ivano Brugnetti',
#  'J. Oliver Macdonald',
#  'Jacek Wszola',
#  'Jackie Joyner-Kersee',
#  'Jackson Scholz',
#  'James Aloysius Bernard Bausch',
#  'James Connolly',
#  'James Edwin Meredith',
#  'James F. Quinn',
#  'James Jett',
#  'James Lightbody',
#  'James Randel Matson',
#  'James Ray Hines',
#  'Jan Zelezny',
#  'Janet Theresa Moreau',
#  'Janusz Kusocinski',
#  'Jason Gardener',
#  'Jason Rouser',
#  'Javier Sotomayor',
#  'Jean Galfione',
#  'Jean Shiley',
#  'Jean Thompson',
#  'Jeanette Bolden',
#  'Jeannette Josephina Maria Witziers-Timmer',
#  'Jearl Miles',
#  'Jeff Henderson',
#  'Jefferson Perez',
#  'Jemima Jelagat Sumgong',
#  'Jeneba Tarmoh',
#  'Jenna Prandini',
#  'Jennifer Suhr',
#  'Jeremiah Alfred Leconey',
#  'Jeremy Wariner',
#  'Jerome Cousins Biffle',
#  'Jesse Owens',
#  'Jesse William Mashburn',
#  'Jessica Ennis',
#  'Jevaughn Minzie',
#  'Jim Thorpe',
#  'Joan Benoit',
#  'Joanna Hayes',
#  'Joaquim Cruz',
#  'Johanna Schaller-Klier',
#  'John Akii-Bua',
#  'John Artur Ljunggren',
#  'John Baxter Taylor',
#  'John Creyghton Ainsworth-Davis',
#  'John Eke',
#  'John Franklin Anderson',
#  'John H. Kuck',
#  'John Jesus Flanagan',
#  'John Joseph Hayes',
#  'John Lloyd Yerman',
#  'John Lovelock',
#  'John Mikaelsson',
#  'John Nathaniel Cartmell',
#  'John Ngugi',
#  'John Rimmer',
#  'John Walker',
#  'John Wesley Jones',
#  'John Winter',
#  'John Youie Woodruff',
#  'Jon Drummond',
#  'Jonathan David Edwards',
#  'Jonni MyyrГ¤',
#  'Josef TernstrГ¶m',
#  'Joseph Barthel',
#  'Joseph Edmund Deakin',
#  'Joseph Guillemot',
#  'Joseph Keter',
#  'Joseph Nathaniel Jr. Deloach',
#  'Josia Thugwane',
#  'Jozef Pribilinec',
#  'Jozef Schmidt',
#  'Jozsef Csermak',
#  'Juan Carlos Zabala',
#  'Juha Tiainen',
#  'Juho Julius Saaristo',
#  'Julius Kariuki',
#  'Julius Korir',
#  'Julius Sang',
#  'Junxia Wang',
#  'Justin Gatlin',
#  'JГјrgen Schult',
#  'Kaj Tapio Rautavaara',
#  'Kamila Skolimowska',
#  'Karin Richert-Balzer',
#  'Karl De Witt Warner',
#  'Karl Hein',
#  'Karoline "Lina" Radke',
#  'Kelly Holmes',
#  'Kelly Willie',
#  'Kemar Bailey-Cole',
#  'Kenenisa Bekele',
#  'Kennedy Kane Mcarthur',
#  'Kenneth Brokenburr',
#  'Kenneth Joseph Matthews',
#  'Kenny Harrison',
#  'Kerron Clement',
#  'Keshia Baker',
#  'Keshorn Walcott',
#  'Kevin Bernard Robinzine',
#  'Kevin Curtis Young',
#  'Khalid Skah',
#  'Kim Graham',
#  'Kipchoge Keino',
#  'Kirani James',
#  'Kitei Son',
#  'Klaus Wolfermann',
#  'Koji Murofushi',
#  'Konstantinos Kenteris',
#  'Konstantinos Tsiclitiras',
#  'Kristo Gantchev Markov',
#  'Krisztian Pars',
#  'Kyle Clemons',
#  'LaShawn Merritt',
#  'LaTasha Colander',
#  'Lamont Smith',
#  'Lars Riedel',
#  'Lashawn Merritt',
#  'Lasse Viren',
#  'Lauri Aleksanteri Lehtinen',
#  'Lauryn Williams',
#  'Lawrence J. Black',
#  'Leamon King',
#  'Lee Barnes',
#  'Lee Calhoun',
#  'Lee Edward Evans',
#  'Lemuel Clarence Houser',
#  'Leo Joseph Sexton',
#  'Leonid Spirin',
#  'Leroy Burrell',
#  'Leslie Laing',
#  'Lia Manoliu',
#  'Lilia Nurutdinova',
#  'Lillian Copeland',
#  'Lillie Mae Leatherwood-King',
#  'Lindy Remigino',
#  'Linetta Wilson',
#  'Linford Christie',
#  'Lioudmila Djigalova',
#  'Liping Wang',
#  'Liudmila Kondratieva',
#  'Livio Berruti',
#  'Loren Murchison',
#  'Lorenzo Christopher Wright',
#  'Louis Alfred Clarke',
#  'Louis Woodard III Jones',
#  'Lucinda Williams',
#  'Ludmila Engquist',
#  'Ludvik Danek',
#  'Luigi Beccali',
#  'Lutz Dombrowski',
#  'Lynn Davies',
#  'Lyudmila Bragina',
#  'Lyudmila Lisenko-Shevtsova',
#  'Madeline Manning-Jackson',
#  'Mae Heriwentha Faggs',
#  'Maicel Malone',
#  'Maksim Tarasov',
#  'Malcolm Maurice Wilkins',
#  'Malvin Groston Whitfield',
#  'Mamo Wolde',
#  'Margaret Johnson Bailes',
#  'Margitta Helmbold-Gummel',
#  'Maria Colon',
#  'Maria Mutola',
#  'Maricica Puica',
#  'Marie-Jose Perec',
#  'Marina Chmonina',
#  'Marita Koch',
#  'Maritza Marten',
#  'Mariya Pinigina',
#  'Mariya Savinova',
#  'Marjorie Jackson',
#  'Mark Lewis-Francis',
#  'Mark Mckoy',
#  'Marlies Oelsner-GГ¶hr',
#  'Marlon Devonish',
#  'Martha B. Hudson',
#  'Martin Emmett Toppino',
#  'Martin Lauer',
#  'Martin Sheridan',
#  'Martina Hellmann',
#  'Mary Denise Bignal-Rand',
#  'Mary Louise Carew',
#  'Mary Peters',
#  'Mary Wineberg',
#  'Matej Toth',
#  'Mathew Birir',
#  'Mathilde (Tilly) Fleischer',
#  'Matthew Centrowitz',
#  'Matthew J. Mcgrath',
#  'Matti Henrik Jarvinen',
#  'Maureen Caird',
#  'Maurice Greene',
#  'Maurizio Damilano',
#  'Maurren Higa Maggi',
#  'Max Emmerich',
#  'Maxwell Lander Parks',
#  'Maxwell W.Maxey Long',
#  'Melaine Walker',
#  'Melvin Emery Patton',
#  'Melvin Jr. Pender',
#  'Melvin Sheppard',
#  'Meseret Defar',
#  'Meyer Prinstein',
#  'Michael D. Stulce',
#  'Michael Denny Larrabee',
#  'Michael Frater',
#  'Michael Johnson',
#  'Michael Marsh',
#  'Michael Mathieu',
#  'Michel Theato',
#  'Micheline Ostermeyer',
#  'Michelle Carter',
#  'Michelle Finn',
#  'Mihaela Penes',
#  'Mike Conley',
#  'Mikhail Linge',
#  'Mikio Oda',
#  'Miklos Nemeth',
#  'Mildred Didrikson',
#  'Mildred Louise Mcdaniel',
#  'Mildrette Netter',
#  'Millard Frank Jr. Hampton',
#  'Millon Wolde',
#  'Miloslava Rezkova-Hubner',
#  'Milton Gray Campbell',
#  'Miruts Yifter',
#  'Mizuki Noguchi',
#  'Mo Farah',
#  'Mohamed Farah',
#  'Mohamed Gammoudi',
#  'Monika Zehrt',
#  'Monique Henderson',
#  'Monique Hennagan',
#  'Morolake Akinosun',
#  'Morris Kirksey',
#  'Moulay Brahim Boutayeb',
#  'Moushaumi Robinson',
#  'Murray Gordon Halberg',
#  'Myrtle Alice Cook',
#  'NIEKERK Wayde Van',
#  'Nabiba Naftali Temu',
#  'Nadezhda Chizhova',
#  'Nadezhda Olizarenko',
#  'Nadezhda Tkachenko',
#  'Nafissatou Thiam',
#  'Nancy jebet Langat',
#  'Naoko Takahashi',
#  'Naoto Tajima',
#  'Nataliia Dobrynska',
#  'Natalya Antyukh',
#  'Natalya Lisovskaya',
#  'Natalya Sadova',
#  'Natasha Hastings',
#  'Nawal El moutawakel',
#  'Nelson Evora',
#  'Nesta Carter',
#  'Nick Hysong',
#  'Nickel Ashmeade',
#  'Nicola Spirig',
#  'Nikolai Avilov',
#  'Nikolai Chernetski',
#  'Nikolai Sidorov',
#  'Nils Schumann',
#  'Nina Romashkova-Ponomareva',
#  'Nina Ziuskova',
#  'Noah Kiprono Ngenyi',
#  'Norma Wilson Crooker-Fleming',
#  'Norman Richard Read',
#  'Norman Taber',
#  'Nouria Merah-Benida',
#  'Nourredine Morceli',
#  'Olga Bondarenko',
#  'Olga Bryzgina',
#  'Olga Fikotova-Connolly',
#  'Olga Gyarmati',
#  'Olga Kaniskina',
#  'Olga Kuzenkova',
#  'Olga Nazarova',
#  'Olga Rypakova',
#  'Olga Shishigina',
#  'Ollan Conley Cassell',
#  'Omar Mcleod',
#  'Osleidys Menendez',
#  'Otis Crandall Davis',
#  'Otis Harris',
#  'Otis Paul Drayton',
#  'Owen Guinn Smith',
#  'Paavo Ilmari YrjГ¶lГ¤',
#  'Paavo Nurmi',
#  'Pamela Jelimo',
#  'Paraskevi Voula Patoulidou',
#  'Patrick Mcdonald',
#  "Patrick O'callaghan",
#  'Patrick Ryan',
#  'Paul Ereng',
#  'Paul Harry Pilgrim',
#  'Paula Ivan',
#  'Pauli Lauri Nevala',
#  'Pauline Elaine Davis',
#  'Pekka Vasala',
#  'Percy Hodge',
#  'Percy Williams',
#  'Peter Frenkel',
#  'Peter Rono',
#  'Peter Snell',
#  'Petra Felke-Meier',
#  'Phyllis Francis',
#  'Pierre Quinon',
#  'Pietro Mennea',
#  'Platt Adams',
#  'Primoz Kozmus',
#  'Pyotr Bolotnikov',
#  'Quincy Watts',
#  'R. William E. Petersson',
#  'Rafer Lewis Johnson',
#  'Ralph Craig',
#  'Ralph Doubell',
#  'Ralph Harold Boston',
#  'Ralph Metcalfe',
#  'Ralph Rose',
#  'Ramon Miller',
#  'Randel Luvelle Williams',
#  'Raul Gonzalez',
#  'Ray Ewry',
#  'Raymond Armstead',
#  'Raymond James Barbuti',
#  'Reginald Walker',
#  'Remigius Valiulis',
#  'Renate Stecher',
#  'Renaud Lavillenie',
#  'Reuben Kosgei',
#  'Ria G. Stalman',
#  'Richard Douglas Fosbury',
#  'Richard Sheldon',
#  'Richard Vaughn Stebbins',
#  'Richmond Landon',
#  'Rita KГјhne',
#  'Robert Alexander Lindsay',
#  'Robert Allan Kiesel',
#  'Robert Esmie',
#  'Robert Garrett',
#  'Robert Harting',
#  'Robert Hayes',
#  'Robert Joseph Morrow',
#  'Robert Kerr',
#  'Robert Keyser Schul',
#  'Robert Korzeniowski',
#  'Robert Lloyd Seagren',
#  'Robert Mathias',
#  'Robert Morton Newburgh Tisdall',
#  'Robert Ouko',
#  'Robert Richards',
#  'Robert Shavlakadze',
#  'Robert Taylor',
#  'Robert Wade King',
#  'Robert Zmelik',
#  'Rochelle Stevens',
#  'Rodney Jr. Milburn',
#  'Roger Kingdom',
#  'Rolf Danneberg',
#  'Roman Sebrle',
#  'Romas Ubartas',
#  'Romuald Klim',
#  'Romy MГјller',
#  'Ronald James Brown',
#  'Ronald John III Freeman',
#  'Ronald Michael Delany',
#  'Ronald Ray Smith',
#  'Rosa Mota',
#  'Rosemarie Witschas-Ackermann',
#  'Roy Braxton Cochran',
#  'Rudolf Bauer',
#  'Ruth Beitia',
#  'Ruth Fuchs',
#  'Ruth Jebet',
#  'Ryan Crouser',
#  'S. Talja',
#  'Sabin William Carr',
#  'Said Aouita',
#  'Sally Janet Jane Gunnell',
#  'Sally Pearson',
#  'Samuel Jones',
#  'Samuel Kamau Wansiru',
#  'Samuel Louis Graddy',
#  'Sandra Perkovic',
#  'Sanya Richards',
#  'Sanya Richards-Ross',
#  'Sara Kolak',
#  'Sara Simeoni',
#  'Sebastian Coe',
#  'Sergei Litvinov',
#  'Sergey Bubka',
#  'Sergey Kirdyapkin',
#  'Sergey Kliugin',
#  'Sevatheda Fynes',
#  'Shaunae Miller',
#  'Shawn Crawford',
#  'Sheila Echols',
#  'Shelly-Ann Fraser',
#  'Shelly-Ann Fraser-Pryce',
#  'Sherone Simpson',
#  'Sherryl Frances Howard',
#  'Shirley Strickland-De La Hunty',
#  'Sidney Atkinson',
#  'Sidney Robinson',
#  'Siegrun Siegl',
#  'Sigrun Wodars',
#  'Silke Renk',
#  'Simeon Garland Iness',
#  'Spyridon Louis',
#  'Stacy Dragila',
#  'Stanislawa Walasiewicz',
#  'Stanley Rowley',
#  'Stefan Holm',
#  'Stefano Baldini',
#  'Stefka Kostadinova',
#  'Stephanie Brown trafton',
#  'Stephen Kiprotich',
#  'Steve Hooker',
#  'Steve Lewis',
#  'Steve Ovett',
#  'Steven Earl Riddick',
#  'Sunder L. Nix',
#  'Svetlana Krivelyova',
#  'Svetlana Masterkova',
#  'Szymon Ziolkowski',
#  'Tadeusz Slusarski',
#  'Tamara Press',
#  'Tamara Tyshkevich',
#  'Tanya Lawrence',
#  'Taoufik Makhloufi',
#  'Tapio Korjus',
#  'Tatiana Goishchik',
#  'Tatiana Kazankina',
#  'Tatiana Kolpakova',
#  'Tatiana Ledovskaya',
#  'Tatiana Prorochenko',
#  'Tatyana Lebedeva',
#  'Tatyana Lysenko',
#  'Tatyana Samolenko-Dorovskikh',
#  'Taylor Ellis-Watson',
#  'Tell Schirnding Berna',
#  'Teresa Barbara Wieczorek-Cieply',
#  'Teresa Sanderson',
#  'Tereza Marinova',
#  'Thiago Braz Da Silva',
#  'Thomas Burke',
#  'Thomas C. Smith',
#  'Thomas Curtis',
#  'Thomas Francis Kiely',
#  'Thomas Hampson',
#  'Thomas Hicks',
#  'Thomas Munkelt',
#  'Thomas Rohler',
#  'Thomas William Courtney',
#  'Thomas William Green',
#  'Tia Hellebaut',
#  'Tianna Bartoletta',
#  'Tianna Madison',
#  'Tiki Gelana',
#  'Tim Montgomery',
#  'Timothy Mack',
#  'Timoty J. Ahearne',
#  'Tirunesh Dibaba',
#  'Toivo Aarne Loukola',
#  'Tomasz Majewski',
#  'Tonique Williams-Darling',
#  'Tony Mcquay',
#  'Tore SjГ¶strand',
#  'Tori Bowie',
#  'Trebisonda Valla',
#  'Trine Hattestad',
#  'Udo Beyer',
#  'Ugo Frigerio',
#  'Ulf Timmermann',
#  'Ulis C. Williams',
#  'Ulrike Meyfarth',
#  'Usain Bolt',
#  'Valentina Yegorova',
#  'Valeri Brumel',
#  'Valerie Adams',
#  'Valerie Ann Brisco-Hooks',
#  'Valerie Vili',
#  'Valeriy Borchin',
#  'Valery Borzov',
#  'Vasili Rudenkov',
#  'Vebjorn Rodal',
#  'Venuste Niyongabo',
#  'Vera Kolashnikova-Krepkina',
#  'Vera Komisova',
#  'Veronica Campbell-Brown',
#  "Victor Henry Augustus D'arcy",
#  'Viktor Bryzgin',
#  'Viktor Markin',
#  'Viktor Rashchupkin',
#  'Viktor Saneev',
#  'Viktor Tsybulenko',
#  'Vilho Immanuel Tuulos',
#  'Ville Ritola',
#  'Vincent Edward Matthews',
#  'Vincent George Rhoden',
#  'Viorica Viscopoleanu',
#  'Virgilijus Alekna',
#  'Vitaly Savin',
#  'Vivian Jepkemoi Cheruiyot',
#  'Vladimir Golubnichy',
#  'Vladimir Kiselev',
#  'Vladimir Krylov',
#  'Vladimir Kuts',
#  'Vladimir Muravyov',
#  'Volker Beck',
#  'Volmari Iso-Hollo',
#  'Vyacheslav Ivanenko',
#  'VГ¤inГ¶ Jeremias SipilГ¤',
#  'Waldemar Cierpinski',
#  'Walter B. John Tewksbury',
#  'Walter Francis Davis',
#  'Walter Mahlendorf',
#  'Walter Thane Baker',
#  'Warren (Rex) Jay Cawley',
#  'Wilbur Marvin Thompson',
#  'Wilfred Bungei',
#  'Wilhelmina Von bremen',
#  'Willi Holdorf',
#  'William Anthony Toomey',
#  'William Applegarth',
#  'William Arthur Carr',
#  'William Bruce Jenner',
#  'William Coales',
#  'William De Hart Hubbard',
#  'William Frank Hamilton',
#  'William Franklin III Porter',
#  'William Henry Nieder',
#  'William Kenneth Carpenter',
#  'William Mills',
#  'William Patrick Jr. O',
#  'William Roberts',
#  'William Samuel Steele',
#  'William Stephenson',
#  'William Tanui',
#  'William Waring Miller',
#  'William Welles Hoyt',
#  'Willie Davenport',
#  'Wilma Rudolph',
#  'Wladyslaw Komar',
#  'Wladyslaw Kozakiewicz',
#  'Wolfgang Nordwig',
#  'Wyndham Halswelle',
#  'Wyomia Tyus',
#  'Xenia Stad-De jong',
#  'Xiang Liu',
#  'Yaak Uudmae',
#  'Yanina Karolchik',
#  'Yanis Lusis',
#  'Yelena Nikolayeva',
#  'Yelena Rouzina',
#  'Yelena Yelesina',
#  'Yohan Blake',
#  'Yordanka Donkova',
#  'Young-Cho Hwang',
#  'Yueling Chen',
#  'Yulia Gushchina',
#  'Yuliya Chermoshanskaya',
#  'Yuliya Nesterenko',
#  'Yuliya Zaripova',
#  'Yumileidi Cumba',
#  'Yuri Sedykh',
#  'Yuri Tarmak',
#  'Yuriy Bilonog',
#  'Yuriy Borzakovskiy',
#  'Yvette Winefred Williams',
#  'Zdzislaw Krzyszkowiak',
#  'Zhen Wang']

# %%
athletes = sorted({medal.athlete for medal in medals})
print(len(athletes))
# Out:
# 999

# %%
athletes[:]
# Out:
# ['Abdon Pamich',
#  'Abebe Bikila',
#  'Abel Kiviat',
#  'Adhemar Ferreira Da Silva',
#  'Adolfo Consolini',
#  'Aksana Miankova',
#  'Alain Mimoun',
#  'Alan Helffrich',
#  'Albert Hill',
#  'Albert Lovejoy Gutterson',
#  'Alberto Cova',
#  'Alberto Juantorena',
#  'Albin Oskar Stenroos',
#  'Aleen Bailey',
#  'Aleksandr Aksinin',
#  'Aleksandra Fedoriva',
#  'Alessandro Andrei',
#  'Alex Schwazer',
#  'Alfred Carleten Gilbert',
#  'Alfred Oerter',
#  'Alfred Tysoe',
#  'Alfredrick Alphonzo Joyner',
#  'Alice Marie Coachman',
#  'Alice Regina Brown',
#  'Alistair Brownlee',
#  'Allan Wells',
#  'Allen Johnson',
#  'Allen Woodring',
#  'Allyson Felix',
#  'Alma Wilfred Richards',
#  'Almaz Ayana',
#  'Alonzo C. Babers',
#  'Alptekin Asli Cakir',
#  'Alvin Harrison',
#  'Alvin Kraenzlein',
#  'Amos Kipwabok Biwott',
#  'Anatoli Bondarchuk',
#  'Anders Garderud',
#  'Andre Lamar Phillips',
#  'Andrea Anderson',
#  'Andreas Thorkildsen',
#  'Andrei Prokofiev',
#  'Andrew Valmon',
#  'Andrew William Stanfield',
#  'Andrey Abduvaliev',
#  'Andrey Perlov',
#  'Andrey Silnov',
#  'Angela Nemeth-Ranky',
#  'Angela Voigt',
#  'Angelo Taylor',
#  'Anier Garcia',
#  'Anisoara Cusmir-Stanciu',
#  'Anita Wlodarczyk',
#  'Ann Elizabeth Packer',
#  'Anna Chicherova',
#  'Annegret Richter-Irrgang',
#  'Annelie Ehrhardt',
#  'Annette Joan Rogers',
#  'Anthony William Winter',
#  'Anthuan Maybank',
#  'Antonio Ricardo Mckay',
#  'Archibald Franklin Williams',
#  'Archie Hahn',
#  'Ariana Washington',
#  'Aries Merritt',
#  'Arlie Alfred Schardt',
#  'Arman Hall',
#  'Armas Rudolf Taipale',
#  'Armin Hary',
#  'Arne Ahman',
#  'Arnie Robinson',
#  'Arnold Jackson',
#  'Arsi Harju',
#  'Arthur Godfrey Kilner Brown',
#  'Arthur Harold Harnden',
#  'Arthur James Robertson',
#  'Arthur Newton',
#  'Arthur Russell',
#  'Arthur Wint',
#  'Arto Harkonen',
#  'Asafa Powell',
#  'Asbel Kipruto Kiprop',
#  'Ashton Eaton',
#  'Astrid Kumbernuss',
#  'Athanasia Tsoumeleka',
#  'Balazs Kiss',
#  'Barbara Ann Ferrell',
#  'Barbara Pearl Jones',
#  'Barbora Spotakova',
#  'Benita Fitzgerald-Brown',
#  'Benjamin Gene Brown',
#  'Bernard Williams iii',
#  'Bernd Cullmann',
#  'Bernd Kannenberg',
#  'Betty Cuthbert',
#  'Beverly Mcdonald',
#  "Bevil Gordon D'Urban Rudd",
#  'Bianca Knight',
#  'Bob Beamon',
#  'Boughera Mohamed El Ouafi',
#  'Brian Lewis',
#  'Brianna Rollins',
#  'Brigitte Rohde',
#  'Brimin Kiprop Kipruto',
#  'Brittney Reese',
#  'Bronislaw Malinowski',
#  'Bruny Surin',
#  'Bryan Clay',
#  'BГ¤rbel Eckert-WГ¶ckel',
#  'Calvin Smith',
#  'Carl Lewis',
#  'Carla Bodendorf',
#  'Carlette D. Guidry-White',
#  'Carlos Lopes',
#  'Carlton Chambers',
#  'Carmelita Jeter',
#  'Carolina Kluft',
#  'Caster Semenya',
#  'Caterine Ibarguen',
#  'Catherine Hardy',
#  'Cathy Freeman',
#  'Cecil Richmond Griffiths',
#  'Chandra Danette Cheeseborough',
#  'Chandra Sturrup',
#  'Charles Asati',
#  'Charles Austin',
#  'Charles Bennett',
#  'Charles Decker Reidpath',
#  'Charles Dvorak',
#  'Charles Edward Borah',
#  'Charles Edward Greene',
#  'Charles Everett Dumas',
#  'Charles Hewes Jr. Moore',
#  'Charles Joseph Bacon',
#  'Charles L. Jenkins',
#  'Charles Lamont Jenkins',
#  'Charles Paddock',
#  'Chioma Ajunwa',
#  'Chris Brown',
#  'Christian Olsson',
#  'Christian Schenk',
#  'Christian Taylor',
#  'Christiane Krause',
#  'Christina Brehmer-Lathan',
#  'Christine Ohuruogu',
#  'Christoph Harting',
#  'Christoph HГ¶hne',
#  'Christopher William Brasher',
#  'Chryste Gaines',
#  'Chuhei Nambu',
#  'Claudia Losch',
#  'Clifford Frederick Bourland',
#  'Colette Besson',
#  'Commodore Cochrane',
#  'Conseslus Kipruto',
#  'Constantina Tomescu',
#  'Cornelius Cooper Johnson',
#  'Courtney Okolo',
#  'Crystal Cox',
#  'Cyrus C. Jr. Young',
#  'Dagmar KГ¤sling',
#  'Dainis Kula',
#  'Daley Thompson',
#  'Dalilah Muhammad',
#  'Dallas Crutcher III Long',
#  "Dan O'brien",
#  'Dana Ingrova-Zatopkova',
#  'Daniel Bautista rocha',
#  'Daniel Everett',
#  'Daniel Kinsey',
#  'Daniel Plaza montero',
#  'Darnell Hall',
#  'Darold Williamson',
#  'Darren Campbell',
#  'David Curtis Munson',
#  'David George Burghley',
#  'David Henry Jacobs',
#  'David James Wottle',
#  'David Lekuta Rudisha',
#  'David Neville',
#  'David Peter Hemery',
#  'David Verburg',
#  'Dawn Harper',
#  'Dayron Robles',
#  'Debbie Ferguson-Mckenzie',
#  'Deborah Flintoff-King',
#  'DeeDee Trotter',
#  'Deedee Trotter',
#  'Delfo Cabrera',
#  'Demetrius Pinder',
#  'Denise Lewis',
#  'Dennis Mitchell',
#  'Deon Marie Hemmings',
#  'Derartu Tulu',
#  'Derek Drouin',
#  'Derek Mills',
#  'Derrick Adkins',
#  'Derrick Brew',
#  'Diamond Dixon',
#  'Dieter Baumann',
#  'Dietmar MГ¶genburg',
#  'Dilshod Nazarov',
#  'Ding Chen',
#  'Doina Besliu-Melinte',
#  'Donald George Bragg',
#  'Donald James Thompson',
#  'Donald Quarrie',
#  'Donovan Bailey',
#  'Doris Maletzki',
#  'Dorothy Louise Ritter',
#  'Douglas Gordon Lowe',
#  'Duncan Mcnaughton',
#  'Dwight Phillips',
#  'Earl Thomson',
#  'Earl Verdelle Young',
#  'Earle Elmer Meadows',
#  'Eddie Tolan',
#  'Edgar Allen Ablowich',
#  'Edith Marie Mcguire',
#  'Edward Barton Hamm',
#  'Edward F. Lindberg',
#  'Edward James Hart',
#  'Edward Lansing Gordon',
#  'Edward Tiffin Cooke',
#  'Edwin Flack',
#  'Edwin Moses',
#  'Eero Berg',
#  'Eero Reino Lehtonen',
#  'Egil Danielsen',
#  'Eino Rastas',
#  'Eino SeppГ¤lГ¤',
#  'Ekaterini Stefanidi',
#  'Elaine Thompson',
#  'Eldice Lewis',
#  'Elena Isinbaeva',
#  'Elena Lashmanova',
#  'Elena Romanova',
#  'Elena Slesarenko',
#  'Elias Katz',
#  'Eliud Kipchoge',
#  'Elizabeth Robinson',
#  'Ellen Stropahl-Streidt',
#  'Ellen Van langen',
#  'Ellery Clark',
#  'Ellina Zvereva',
#  'Elmer Konstantin Niklander',
#  'Elvira Ozolina',
#  'Elzbieta Dunska-Krzesinska',
#  'Emerson Lane Spencer',
#  'Emil Robert Voigt',
#  'Emil Zatopek',
#  'English Gardner',
#  'Eric Henry Liddell',
#  'Eric Lemming',
#  'Eric Randolph Barnes',
#  'Erik H. Lundqvist',
#  'Erki Nool',
#  'Ernesto Canto gudino',
#  'Esther Cornelia Brand',
#  'Esther Jones',
#  'Ethel Catherwood',
#  'Ethel M. Smith',
#  'Etienne Desmarteau',
#  'Evelin Schlaak-Jahl',
#  'Evelyn Ashford',
#  'Evelyn Furtsch',
#  'Evgeniya Polyakova',
#  'Ewa Klobukowska',
#  'Ezekiel Kemboi',
#  'Faina Melnik',
#  'Faith Chepngetich Kipyegon',
#  'Fani Chalkia',
#  'Fanny Blankers-Koen',
#  'Fanny Rosenfeld',
#  'Fatuma Roba',
#  'Felix Sanchez',
#  'Ferdinand Reinhardt Bie',
#  'Fermin Cacho ruiz',
#  'Fernanda Ribeiro',
#  'Finis Dean Smith',
#  'Florence Griffith-Joyner',
#  'Fluer Northey Mellor-Wenham',
#  'Forrest Grady Towns',
#  'Forrest Smithson',
#  'Foy Draper',
#  'Francena McCorory',
#  'Francena Mccorory',
#  'Francis C. Irons',
#  'Francis Hussey',
#  'Francis Jarvis',
#  'Francoise Mbango etone',
#  'Frank Charles Shorter',
#  'Frank Clifford Wykoff',
#  'Frank Foss',
#  'Frank Loomis',
#  'Frans Wilhelmi PГ¶rhГ¶lГ¤',
#  'Frederick Delmont Tootell',
#  'Frederick Ferdinand Wolff',
#  'Frederick Kelly',
#  'Frederick Morgan Hansen',
#  'Frederick Morgan Taylor',
#  'Frederick Pitt Alderman',
#  'Frederick Schule',
#  'Frederick Vaughn Newhouse',
#  'Frederik Teudor Koskenniemi',
#  'Frej Liewendhal',
#  'Gabriela Szabo',
#  'Gabriella Dorio',
#  'Gail Devers',
#  'Galina Zybina',
#  'Gaston Etienne Reiff',
#  'Gaston Roelants',
#  'Gelindo Bordin',
#  'Gennadi Avdeenko',
#  'George Edward Larner',
#  'George Goulding',
#  'George Hetzel Baird',
#  'George J. Jr. Saling',
#  'George Lawrence James',
#  'George Orton',
#  'George Underwood',
#  'George V. Bonhag',
#  'Gerald A. Tinker',
#  'Gerald Howard Ashworth',
#  'Gerd Kanter',
#  'Gerd Wessig',
#  'Gerda Johanna Marie Van der kade-Koudijs',
#  'Gerhard (Gerd) StГ¶ck',
#  'Gezahegne Abera',
#  'Ghada Shouaa',
#  'Gil Roberts',
#  'Gisela Mauermayer',
#  'Giuseppe Dordoni',
#  'Glenn Ashby Davis',
#  'Glenn Edward Morris',
#  'Glenn Foster Hardin',
#  'Glenroy Gilbert',
#  'Glyniss Leanne Nunn-Saunders-Cearns',
#  'Godfrey Lionel Rampling',
#  'Greg Rutherford',
#  'Gregory Curtis Bell',
#  'Gulnara Galkina-Samitova',
#  'Gunnar HГ¶ckert',
#  'Gustav Lindblom',
#  'Guy Drut',
#  'Guy Montagu Butler',
#  'Gwen Jorgensen',
#  'Gwen Torrence',
#  'Gyula Zsivotzky',
#  'Haile Gebrselassie',
#  'Halina Herrmann-Gorecka-Richter',
#  'Halina Konopacka',
#  'Hannes Kolehmainen',
#  'Hans Woellke',
#  'Harold Abrahams',
#  'Harold Marion Osborn',
#  'Harold Norwood Ewell',
#  'Harold Vincent Connolly',
#  'Harri Edvin Larva',
#  'Harriett Claiborne Bland',
#  'Harrison Dillard',
#  'Harry Butch . Reynolds',
#  'Harry Franklin Porter',
#  'Harry Hillman',
#  'Harry Stoddard Babcock',
#  'Hartwig Gauder',
#  'Harvey Edward Glance',
#  'Hasely Crawford',
#  'Hassiba Boulmerka',
#  'Hayes Jones',
#  'Hector Harold Whitlock',
#  'Hector Monroe Dyer',
#  'Heidemarie Rosendahl',
#  'Heike Drechsler',
#  'Heike Henkel',
#  'Heikki Liimatainen',
#  'Helen Herring Stephens',
#  'Helga Seidler',
#  'Helge Andreas LГ¶vland',
#  'Heli Orvokki Rantanen',
#  'Henry Argue Russell',
#  'Henry Carr',
#  'Henry Eriksson',
#  'Henry Louis Scott',
#  'Henry Maitland Mackintosh',
#  'Herbert Elliott',
#  'Herbert Mckenley',
#  'Herman Ronald Frazier',
#  'Hermine (Herma) Bauma',
#  'Hezekiah Munyoro Nyamau',
#  'Hicham El guerrouj',
#  'Hildegard Falck-Janze',
#  'Hjalmar Andersson',
#  'Hong Liu',
#  'Horace Hallock Brown',
#  'Horace III Ashenfelter',
#  'Howard Valentine',
#  'Hugo K. Wieslander',
#  'Huina Xing',
#  'Ibolya Csak',
#  'Ilke Wyludda',
#  'Ilmari Salminen',
#  'Ilona Schoknecht-Slupianek',
#  'Imre Nemeth',
#  'Inese Yaunzeme',
#  'Inessa Kravets',
#  'Inger Miller',
#  'Ingrid Auerswald-Lange',
#  'Ingrid Becker-Mickler',
#  'Iolanda Balas',
#  'Ira James Murchison',
#  'Irena Szewinska',
#  'Irina Nazarova',
#  'Irina Privalova',
#  'Irving Baxter',
#  'Irving Jahir Saladino aranda',
#  'Iryna Press',
#  'Ivan Dresser',
#  'Ivan Pedroso',
#  'Ivan Ukhov',
#  'Ivan William Fuqua',
#  'Ivanka Mikailova Christova-Todorova',
#  'Ivano Brugnetti',
#  'J. Oliver Macdonald',
#  'Jacek Wszola',
#  'Jackie Joyner-Kersee',
#  'Jackson Scholz',
#  'James Aloysius Bernard Bausch',
#  'James Connolly',
#  'James Edwin Meredith',
#  'James F. Quinn',
#  'James Jett',
#  'James Lightbody',
#  'James Randel Matson',
#  'James Ray Hines',
#  'Jan Zelezny',
#  'Janet Theresa Moreau',
#  'Janusz Kusocinski',
#  'Jason Gardener',
#  'Jason Rouser',
#  'Javier Sotomayor',
#  'Jean Galfione',
#  'Jean Shiley',
#  'Jean Thompson',
#  'Jeanette Bolden',
#  'Jeannette Josephina Maria Witziers-Timmer',
#  'Jearl Miles',
#  'Jeff Henderson',
#  'Jefferson Perez',
#  'Jemima Jelagat Sumgong',
#  'Jeneba Tarmoh',
#  'Jenna Prandini',
#  'Jennifer Suhr',
#  'Jeremiah Alfred Leconey',
#  'Jeremy Wariner',
#  'Jerome Cousins Biffle',
#  'Jesse Owens',
#  'Jesse William Mashburn',
#  'Jessica Ennis',
#  'Jevaughn Minzie',
#  'Jim Thorpe',
#  'Joan Benoit',
#  'Joanna Hayes',
#  'Joaquim Cruz',
#  'Johanna Schaller-Klier',
#  'John Akii-Bua',
#  'John Artur Ljunggren',
#  'John Baxter Taylor',
#  'John Creyghton Ainsworth-Davis',
#  'John Eke',
#  'John Franklin Anderson',
#  'John H. Kuck',
#  'John Jesus Flanagan',
#  'John Joseph Hayes',
#  'John Lloyd Yerman',
#  'John Lovelock',
#  'John Mikaelsson',
#  'John Nathaniel Cartmell',
#  'John Ngugi',
#  'John Rimmer',
#  'John Walker',
#  'John Wesley Jones',
#  'John Winter',
#  'John Youie Woodruff',
#  'Jon Drummond',
#  'Jonathan David Edwards',
#  'Jonni MyyrГ¤',
#  'Josef TernstrГ¶m',
#  'Joseph Barthel',
#  'Joseph Edmund Deakin',
#  'Joseph Guillemot',
#  'Joseph Keter',
#  'Joseph Nathaniel Jr. Deloach',
#  'Josia Thugwane',
#  'Jozef Pribilinec',
#  'Jozef Schmidt',
#  'Jozsef Csermak',
#  'Juan Carlos Zabala',
#  'Juha Tiainen',
#  'Juho Julius Saaristo',
#  'Julius Kariuki',
#  'Julius Korir',
#  'Julius Sang',
#  'Junxia Wang',
#  'Justin Gatlin',
#  'JГјrgen Schult',
#  'Kaj Tapio Rautavaara',
#  'Kamila Skolimowska',
#  'Karin Richert-Balzer',
#  'Karl De Witt Warner',
#  'Karl Hein',
#  'Karoline "Lina" Radke',
#  'Kelly Holmes',
#  'Kelly Willie',
#  'Kemar Bailey-Cole',
#  'Kenenisa Bekele',
#  'Kennedy Kane Mcarthur',
#  'Kenneth Brokenburr',
#  'Kenneth Joseph Matthews',
#  'Kenny Harrison',
#  'Kerron Clement',
#  'Keshia Baker',
#  'Keshorn Walcott',
#  'Kevin Bernard Robinzine',
#  'Kevin Curtis Young',
#  'Khalid Skah',
#  'Kim Graham',
#  'Kipchoge Keino',
#  'Kirani James',
#  'Kitei Son',
#  'Klaus Wolfermann',
#  'Koji Murofushi',
#  'Konstantinos Kenteris',
#  'Konstantinos Tsiclitiras',
#  'Kristo Gantchev Markov',
#  'Krisztian Pars',
#  'Kyle Clemons',
#  'LaShawn Merritt',
#  'LaTasha Colander',
#  'Lamont Smith',
#  'Lars Riedel',
#  'Lashawn Merritt',
#  'Lasse Viren',
#  'Lauri Aleksanteri Lehtinen',
#  'Lauryn Williams',
#  'Lawrence J. Black',
#  'Leamon King',
#  'Lee Barnes',
#  'Lee Calhoun',
#  'Lee Edward Evans',
#  'Lemuel Clarence Houser',
#  'Leo Joseph Sexton',
#  'Leonid Spirin',
#  'Leroy Burrell',
#  'Leslie Laing',
#  'Lia Manoliu',
#  'Lilia Nurutdinova',
#  'Lillian Copeland',
#  'Lillie Mae Leatherwood-King',
#  'Lindy Remigino',
#  'Linetta Wilson',
#  'Linford Christie',
#  'Lioudmila Djigalova',
#  'Liping Wang',
#  'Liudmila Kondratieva',
#  'Livio Berruti',
#  'Loren Murchison',
#  'Lorenzo Christopher Wright',
#  'Louis Alfred Clarke',
#  'Louis Woodard III Jones',
#  'Lucinda Williams',
#  'Ludmila Engquist',
#  'Ludvik Danek',
#  'Luigi Beccali',
#  'Lutz Dombrowski',
#  'Lynn Davies',
#  'Lyudmila Bragina',
#  'Lyudmila Lisenko-Shevtsova',
#  'Madeline Manning-Jackson',
#  'Mae Heriwentha Faggs',
#  'Maicel Malone',
#  'Maksim Tarasov',
#  'Malcolm Maurice Wilkins',
#  'Malvin Groston Whitfield',
#  'Mamo Wolde',
#  'Margaret Johnson Bailes',
#  'Margitta Helmbold-Gummel',
#  'Maria Colon',
#  'Maria Mutola',
#  'Maricica Puica',
#  'Marie-Jose Perec',
#  'Marina Chmonina',
#  'Marita Koch',
#  'Maritza Marten',
#  'Mariya Pinigina',
#  'Mariya Savinova',
#  'Marjorie Jackson',
#  'Mark Lewis-Francis',
#  'Mark Mckoy',
#  'Marlies Oelsner-GГ¶hr',
#  'Marlon Devonish',
#  'Martha B. Hudson',
#  'Martin Emmett Toppino',
#  'Martin Lauer',
#  'Martin Sheridan',
#  'Martina Hellmann',
#  'Mary Denise Bignal-Rand',
#  'Mary Louise Carew',
#  'Mary Peters',
#  'Mary Wineberg',
#  'Matej Toth',
#  'Mathew Birir',
#  'Mathilde (Tilly) Fleischer',
#  'Matthew Centrowitz',
#  'Matthew J. Mcgrath',
#  'Matti Henrik Jarvinen',
#  'Maureen Caird',
#  'Maurice Greene',
#  'Maurizio Damilano',
#  'Maurren Higa Maggi',
#  'Max Emmerich',
#  'Maxwell Lander Parks',
#  'Maxwell W.Maxey Long',
#  'Melaine Walker',
#  'Melvin Emery Patton',
#  'Melvin Jr. Pender',
#  'Melvin Sheppard',
#  'Meseret Defar',
#  'Meyer Prinstein',
#  'Michael D. Stulce',
#  'Michael Denny Larrabee',
#  'Michael Frater',
#  'Michael Johnson',
#  'Michael Marsh',
#  'Michael Mathieu',
#  'Michel Theato',
#  'Micheline Ostermeyer',
#  'Michelle Carter',
#  'Michelle Finn',
#  'Mihaela Penes',
#  'Mike Conley',
#  'Mikhail Linge',
#  'Mikio Oda',
#  'Miklos Nemeth',
#  'Mildred Didrikson',
#  'Mildred Louise Mcdaniel',
#  'Mildrette Netter',
#  'Millard Frank Jr. Hampton',
#  'Millon Wolde',
#  'Miloslava Rezkova-Hubner',
#  'Milton Gray Campbell',
#  'Miruts Yifter',
#  'Mizuki Noguchi',
#  'Mo Farah',
#  'Mohamed Farah',
#  'Mohamed Gammoudi',
#  'Monika Zehrt',
#  'Monique Henderson',
#  'Monique Hennagan',
#  'Morolake Akinosun',
#  'Morris Kirksey',
#  'Moulay Brahim Boutayeb',
#  'Moushaumi Robinson',
#  'Murray Gordon Halberg',
#  'Myrtle Alice Cook',
#  'NIEKERK Wayde Van',
#  'Nabiba Naftali Temu',
#  'Nadezhda Chizhova',
#  'Nadezhda Olizarenko',
#  'Nadezhda Tkachenko',
#  'Nafissatou Thiam',
#  'Nancy jebet Langat',
#  'Naoko Takahashi',
#  'Naoto Tajima',
#  'Nataliia Dobrynska',
#  'Natalya Antyukh',
#  'Natalya Lisovskaya',
#  'Natalya Sadova',
#  'Natasha Hastings',
#  'Nawal El moutawakel',
#  'Nelson Evora',
#  'Nesta Carter',
#  'Nick Hysong',
#  'Nickel Ashmeade',
#  'Nicola Spirig',
#  'Nikolai Avilov',
#  'Nikolai Chernetski',
#  'Nikolai Sidorov',
#  'Nils Schumann',
#  'Nina Romashkova-Ponomareva',
#  'Nina Ziuskova',
#  'Noah Kiprono Ngenyi',
#  'Norma Wilson Crooker-Fleming',
#  'Norman Richard Read',
#  'Norman Taber',
#  'Nouria Merah-Benida',
#  'Nourredine Morceli',
#  'Olga Bondarenko',
#  'Olga Bryzgina',
#  'Olga Fikotova-Connolly',
#  'Olga Gyarmati',
#  'Olga Kaniskina',
#  'Olga Kuzenkova',
#  'Olga Nazarova',
#  'Olga Rypakova',
#  'Olga Shishigina',
#  'Ollan Conley Cassell',
#  'Omar Mcleod',
#  'Osleidys Menendez',
#  'Otis Crandall Davis',
#  'Otis Harris',
#  'Otis Paul Drayton',
#  'Owen Guinn Smith',
#  'Paavo Ilmari YrjГ¶lГ¤',
#  'Paavo Nurmi',
#  'Pamela Jelimo',
#  'Paraskevi Voula Patoulidou',
#  'Patrick Mcdonald',
#  "Patrick O'callaghan",
#  'Patrick Ryan',
#  'Paul Ereng',
#  'Paul Harry Pilgrim',
#  'Paula Ivan',
#  'Pauli Lauri Nevala',
#  'Pauline Elaine Davis',
#  'Pekka Vasala',
#  'Percy Hodge',
#  'Percy Williams',
#  'Peter Frenkel',
#  'Peter Rono',
#  'Peter Snell',
#  'Petra Felke-Meier',
#  'Phyllis Francis',
#  'Pierre Quinon',
#  'Pietro Mennea',
#  'Platt Adams',
#  'Primoz Kozmus',
#  'Pyotr Bolotnikov',
#  'Quincy Watts',
#  'R. William E. Petersson',
#  'Rafer Lewis Johnson',
#  'Ralph Craig',
#  'Ralph Doubell',
#  'Ralph Harold Boston',
#  'Ralph Metcalfe',
#  'Ralph Rose',
#  'Ramon Miller',
#  'Randel Luvelle Williams',
#  'Raul Gonzalez',
#  'Ray Ewry',
#  'Raymond Armstead',
#  'Raymond James Barbuti',
#  'Reginald Walker',
#  'Remigius Valiulis',
#  'Renate Stecher',
#  'Renaud Lavillenie',
#  'Reuben Kosgei',
#  'Ria G. Stalman',
#  'Richard Douglas Fosbury',
#  'Richard Sheldon',
#  'Richard Vaughn Stebbins',
#  'Richmond Landon',
#  'Rita KГјhne',
#  'Robert Alexander Lindsay',
#  'Robert Allan Kiesel',
#  'Robert Esmie',
#  'Robert Garrett',
#  'Robert Harting',
#  'Robert Hayes',
#  'Robert Joseph Morrow',
#  'Robert Kerr',
#  'Robert Keyser Schul',
#  'Robert Korzeniowski',
#  'Robert Lloyd Seagren',
#  'Robert Mathias',
#  'Robert Morton Newburgh Tisdall',
#  'Robert Ouko',
#  'Robert Richards',
#  'Robert Shavlakadze',
#  'Robert Taylor',
#  'Robert Wade King',
#  'Robert Zmelik',
#  'Rochelle Stevens',
#  'Rodney Jr. Milburn',
#  'Roger Kingdom',
#  'Rolf Danneberg',
#  'Roman Sebrle',
#  'Romas Ubartas',
#  'Romuald Klim',
#  'Romy MГјller',
#  'Ronald James Brown',
#  'Ronald John III Freeman',
#  'Ronald Michael Delany',
#  'Ronald Ray Smith',
#  'Rosa Mota',
#  'Rosemarie Witschas-Ackermann',
#  'Roy Braxton Cochran',
#  'Rudolf Bauer',
#  'Ruth Beitia',
#  'Ruth Fuchs',
#  'Ruth Jebet',
#  'Ryan Crouser',
#  'S. Talja',
#  'Sabin William Carr',
#  'Said Aouita',
#  'Sally Janet Jane Gunnell',
#  'Sally Pearson',
#  'Samuel Jones',
#  'Samuel Kamau Wansiru',
#  'Samuel Louis Graddy',
#  'Sandra Perkovic',
#  'Sanya Richards',
#  'Sanya Richards-Ross',
#  'Sara Kolak',
#  'Sara Simeoni',
#  'Sebastian Coe',
#  'Sergei Litvinov',
#  'Sergey Bubka',
#  'Sergey Kirdyapkin',
#  'Sergey Kliugin',
#  'Sevatheda Fynes',
#  'Shaunae Miller',
#  'Shawn Crawford',
#  'Sheila Echols',
#  'Shelly-Ann Fraser',
#  'Shelly-Ann Fraser-Pryce',
#  'Sherone Simpson',
#  'Sherryl Frances Howard',
#  'Shirley Strickland-De La Hunty',
#  'Sidney Atkinson',
#  'Sidney Robinson',
#  'Siegrun Siegl',
#  'Sigrun Wodars',
#  'Silke Renk',
#  'Simeon Garland Iness',
#  'Spyridon Louis',
#  'Stacy Dragila',
#  'Stanislawa Walasiewicz',
#  'Stanley Rowley',
#  'Stefan Holm',
#  'Stefano Baldini',
#  'Stefka Kostadinova',
#  'Stephanie Brown trafton',
#  'Stephen Kiprotich',
#  'Steve Hooker',
#  'Steve Lewis',
#  'Steve Ovett',
#  'Steven Earl Riddick',
#  'Sunder L. Nix',
#  'Svetlana Krivelyova',
#  'Svetlana Masterkova',
#  'Szymon Ziolkowski',
#  'Tadeusz Slusarski',
#  'Tamara Press',
#  'Tamara Tyshkevich',
#  'Tanya Lawrence',
#  'Taoufik Makhloufi',
#  'Tapio Korjus',
#  'Tatiana Goishchik',
#  'Tatiana Kazankina',
#  'Tatiana Kolpakova',
#  'Tatiana Ledovskaya',
#  'Tatiana Prorochenko',
#  'Tatyana Lebedeva',
#  'Tatyana Lysenko',
#  'Tatyana Samolenko-Dorovskikh',
#  'Taylor Ellis-Watson',
#  'Tell Schirnding Berna',
#  'Teresa Barbara Wieczorek-Cieply',
#  'Teresa Sanderson',
#  'Tereza Marinova',
#  'Thiago Braz Da Silva',
#  'Thomas Burke',
#  'Thomas C. Smith',
#  'Thomas Curtis',
#  'Thomas Francis Kiely',
#  'Thomas Hampson',
#  'Thomas Hicks',
#  'Thomas Munkelt',
#  'Thomas Rohler',
#  'Thomas William Courtney',
#  'Thomas William Green',
#  'Tia Hellebaut',
#  'Tianna Bartoletta',
#  'Tianna Madison',
#  'Tiki Gelana',
#  'Tim Montgomery',
#  'Timothy Mack',
#  'Timoty J. Ahearne',
#  'Tirunesh Dibaba',
#  'Toivo Aarne Loukola',
#  'Tomasz Majewski',
#  'Tonique Williams-Darling',
#  'Tony Mcquay',
#  'Tore SjГ¶strand',
#  'Tori Bowie',
#  'Trebisonda Valla',
#  'Trine Hattestad',
#  'Udo Beyer',
#  'Ugo Frigerio',
#  'Ulf Timmermann',
#  'Ulis C. Williams',
#  'Ulrike Meyfarth',
#  'Usain Bolt',
#  'Valentina Yegorova',
#  'Valeri Brumel',
#  'Valerie Adams',
#  'Valerie Ann Brisco-Hooks',
#  'Valerie Vili',
#  'Valeriy Borchin',
#  'Valery Borzov',
#  'Vasili Rudenkov',
#  'Vebjorn Rodal',
#  'Venuste Niyongabo',
#  'Vera Kolashnikova-Krepkina',
#  'Vera Komisova',
#  'Veronica Campbell-Brown',
#  "Victor Henry Augustus D'arcy",
#  'Viktor Bryzgin',
#  'Viktor Markin',
#  'Viktor Rashchupkin',
#  'Viktor Saneev',
#  'Viktor Tsybulenko',
#  'Vilho Immanuel Tuulos',
#  'Ville Ritola',
#  'Vincent Edward Matthews',
#  'Vincent George Rhoden',
#  'Viorica Viscopoleanu',
#  'Virgilijus Alekna',
#  'Vitaly Savin',
#  'Vivian Jepkemoi Cheruiyot',
#  'Vladimir Golubnichy',
#  'Vladimir Kiselev',
#  'Vladimir Krylov',
#  'Vladimir Kuts',
#  'Vladimir Muravyov',
#  'Volker Beck',
#  'Volmari Iso-Hollo',
#  'Vyacheslav Ivanenko',
#  'VГ¤inГ¶ Jeremias SipilГ¤',
#  'Waldemar Cierpinski',
#  'Walter B. John Tewksbury',
#  'Walter Francis Davis',
#  'Walter Mahlendorf',
#  'Walter Thane Baker',
#  'Warren (Rex) Jay Cawley',
#  'Wilbur Marvin Thompson',
#  'Wilfred Bungei',
#  'Wilhelmina Von bremen',
#  'Willi Holdorf',
#  'William Anthony Toomey',
#  'William Applegarth',
#  'William Arthur Carr',
#  'William Bruce Jenner',
#  'William Coales',
#  'William De Hart Hubbard',
#  'William Frank Hamilton',
#  'William Franklin III Porter',
#  'William Henry Nieder',
#  'William Kenneth Carpenter',
#  'William Mills',
#  'William Patrick Jr. O',
#  'William Roberts',
#  'William Samuel Steele',
#  'William Stephenson',
#  'William Tanui',
#  'William Waring Miller',
#  'William Welles Hoyt',
#  'Willie Davenport',
#  'Wilma Rudolph',
#  'Wladyslaw Komar',
#  'Wladyslaw Kozakiewicz',
#  'Wolfgang Nordwig',
#  'Wyndham Halswelle',
#  'Wyomia Tyus',
#  'Xenia Stad-De jong',
#  'Xiang Liu',
#  'Yaak Uudmae',
#  'Yanina Karolchik',
#  'Yanis Lusis',
#  'Yelena Nikolayeva',
#  'Yelena Rouzina',
#  'Yelena Yelesina',
#  'Yohan Blake',
#  'Yordanka Donkova',
#  'Young-Cho Hwang',
#  'Yueling Chen',
#  'Yulia Gushchina',
#  'Yuliya Chermoshanskaya',
#  'Yuliya Nesterenko',
#  'Yuliya Zaripova',
#  'Yumileidi Cumba',
#  'Yuri Sedykh',
#  'Yuri Tarmak',
#  'Yuriy Bilonog',
#  'Yuriy Borzakovskiy',
#  'Yvette Winefred Williams',
#  'Zdzislaw Krzyszkowiak',
#  'Zhen Wang']

# %%
temp = [1,1,2,3,4,5,5]

temp1 = {i for i in temp}

print(temp1)

temp1 = []

for i in temp:
    temp1.append(i)
    
print(temp1)
# Out:
# {1, 2, 3, 4, 5}
# [1, 1, 2, 3, 4, 5, 5]

# %%
winners_100m = {medal.athlete for medal in medals if '100m' in medal.event}
winners_200m = {medal.athlete for medal in medals if '200m' in medal.event}

# %%
winners_100m
# Out:
# {'Aleen Bailey',
#  'Aleksandr Aksinin',
#  'Aleksandra Fedoriva',
#  'Alice Regina Brown',
#  'Allan Wells',
#  'Allyson Felix',
#  'Andrei Prokofiev',
#  'Andrew William Stanfield',
#  'Annegret Richter-Irrgang',
#  'Annelie Ehrhardt',
#  'Annette Joan Rogers',
#  'Archie Hahn',
#  'Ariana Washington',
#  'Armin Hary',
#  'Asafa Powell',
#  'Barbara Ann Ferrell',
#  'Barbara Pearl Jones',
#  'Benita Fitzgerald-Brown',
#  'Bernard Williams iii',
#  'Bernd Cullmann',
#  'Betty Cuthbert',
#  'Beverly Mcdonald',
#  'Bianca Knight',
#  'Brian Lewis',
#  'Brianna Rollins',
#  'Bruny Surin',
#  'BГ¤rbel Eckert-WГ¶ckel',
#  'Calvin Smith',
#  'Carl Lewis',
#  'Carla Bodendorf',
#  'Carlette D. Guidry-White',
#  'Carlton Chambers',
#  'Carmelita Jeter',
#  'Catherine Hardy',
#  'Chandra Danette Cheeseborough',
#  'Chandra Sturrup',
#  'Charles Edward Borah',
#  'Charles Edward Greene',
#  'Charles Paddock',
#  'Christiane Krause',
#  'Chryste Gaines',
#  'Darren Campbell',
#  'David Henry Jacobs',
#  'Dawn Harper',
#  'Debbie Ferguson-Mckenzie',
#  'Dennis Mitchell',
#  'Donovan Bailey',
#  'Eddie Tolan',
#  'Edward James Hart',
#  'Elaine Thompson',
#  'Eldice Lewis',
#  'Elizabeth Robinson',
#  'English Gardner',
#  'Esther Jones',
#  'Ethel M. Smith',
#  'Evelyn Ashford',
#  'Evelyn Furtsch',
#  'Evgeniya Polyakova',
#  'Ewa Klobukowska',
#  'Fanny Blankers-Koen',
#  'Fanny Rosenfeld',
#  'Finis Dean Smith',
#  'Florence Griffith-Joyner',
#  'Fluer Northey Mellor-Wenham',
#  'Foy Draper',
#  'Francis Hussey',
#  'Francis Jarvis',
#  'Frank Clifford Wykoff',
#  'Gail Devers',
#  'Gerald A. Tinker',
#  'Gerald Howard Ashworth',
#  'Gerda Johanna Marie Van der kade-Koudijs',
#  'Glenroy Gilbert',
#  'Gwen Torrence',
#  'Halina Herrmann-Gorecka-Richter',
#  'Harold Abrahams',
#  'Harold Norwood Ewell',
#  'Harriett Claiborne Bland',
#  'Harrison Dillard',
#  'Harvey Edward Glance',
#  'Hasely Crawford',
#  'Hector Monroe Dyer',
#  'Heidemarie Rosendahl',
#  'Helen Herring Stephens',
#  'Henry Argue Russell',
#  'Henry Maitland Mackintosh',
#  'Inger Miller',
#  'Ingrid Auerswald-Lange',
#  'Ingrid Becker-Mickler',
#  'Ira James Murchison',
#  'Irena Szewinska',
#  'Jackson Scholz',
#  'James F. Quinn',
#  'James Jett',
#  'James Ray Hines',
#  'Janet Theresa Moreau',
#  'Jason Gardener',
#  'Jean Thompson',
#  'Jeanette Bolden',
#  'Jeannette Josephina Maria Witziers-Timmer',
#  'Jeneba Tarmoh',
#  'Jenna Prandini',
#  'Jeremiah Alfred Leconey',
#  'Jesse Owens',
#  'Jevaughn Minzie',
#  'Joanna Hayes',
#  'Johanna Schaller-Klier',
#  'John Wesley Jones',
#  'Jon Drummond',
#  'Justin Gatlin',
#  'Kemar Bailey-Cole',
#  'Kenneth Brokenburr',
#  'Lauryn Williams',
#  'Lawrence J. Black',
#  'Leamon King',
#  'Leroy Burrell',
#  'Lindy Remigino',
#  'Linford Christie',
#  'Liudmila Kondratieva',
#  'Loren Murchison',
#  'Lorenzo Christopher Wright',
#  'Louis Alfred Clarke',
#  'Lucinda Williams',
#  'Ludmila Engquist',
#  'Mae Heriwentha Faggs',
#  'Margaret Johnson Bailes',
#  'Marjorie Jackson',
#  'Mark Lewis-Francis',
#  'Marlies Oelsner-GГ¶hr',
#  'Marlon Devonish',
#  'Martha B. Hudson',
#  'Martin Emmett Toppino',
#  'Martin Lauer',
#  'Mary Louise Carew',
#  'Maurice Greene',
#  'Melvin Emery Patton',
#  'Melvin Jr. Pender',
#  'Michael Frater',
#  'Michael Marsh',
#  'Michelle Finn',
#  'Mildrette Netter',
#  'Millard Frank Jr. Hampton',
#  'Morolake Akinosun',
#  'Morris Kirksey',
#  'Myrtle Alice Cook',
#  'Nesta Carter',
#  'Nickel Ashmeade',
#  'Nikolai Sidorov',
#  'Norma Wilson Crooker-Fleming',
#  'Olga Shishigina',
#  'Otis Paul Drayton',
#  'Paraskevi Voula Patoulidou',
#  'Pauline Elaine Davis',
#  'Percy Williams',
#  'Ralph Craig',
#  'Ralph Metcalfe',
#  'Reginald Walker',
#  'Renate Stecher',
#  'Richard Vaughn Stebbins',
#  'Robert Allan Kiesel',
#  'Robert Esmie',
#  'Robert Hayes',
#  'Robert Joseph Morrow',
#  'Robert Taylor',
#  'Romy MГјller',
#  'Ronald James Brown',
#  'Ronald Ray Smith',
#  'Sally Pearson',
#  'Samuel Louis Graddy',
#  'Sevatheda Fynes',
#  'Sheila Echols',
#  'Shelly-Ann Fraser',
#  'Shelly-Ann Fraser-Pryce',
#  'Sherone Simpson',
#  'Shirley Strickland-De La Hunty',
#  'Stanislawa Walasiewicz',
#  'Steven Earl Riddick',
#  'Tanya Lawrence',
#  'Teresa Barbara Wieczorek-Cieply',
#  'Thomas Burke',
#  'Tianna Bartoletta',
#  'Tianna Madison',
#  'Tim Montgomery',
#  'Tori Bowie',
#  'Usain Bolt',
#  'Valery Borzov',
#  'Vera Komisova',
#  'Veronica Campbell-Brown',
#  "Victor Henry Augustus D'arcy",
#  'Viktor Bryzgin',
#  'Vitaly Savin',
#  'Vladimir Krylov',
#  'Vladimir Muravyov',
#  'Walter Mahlendorf',
#  'Walter Thane Baker',
#  'Wilhelmina Von bremen',
#  'William Applegarth',
#  'Wilma Rudolph',
#  'Wyomia Tyus',
#  'Xenia Stad-De jong',
#  'Yohan Blake',
#  'Yordanka Donkova',
#  'Yulia Gushchina',
#  'Yuliya Chermoshanskaya',
#  'Yuliya Nesterenko'}

# %%
winners_200m
# Out:
# {'Allen Woodring',
#  'Allyson Felix',
#  'Alvin Kraenzlein',
#  'Andrew William Stanfield',
#  'Archie Hahn',
#  'Arthur Russell',
#  'Betty Cuthbert',
#  'BГ¤rbel Eckert-WГ¶ckel',
#  'Carl Lewis',
#  'Donald Quarrie',
#  'Eddie Tolan',
#  'Edith Marie Mcguire',
#  'Elaine Thompson',
#  'Fanny Blankers-Koen',
#  'Florence Griffith-Joyner',
#  'Gwen Torrence',
#  'Harry Hillman',
#  'Henry Carr',
#  'Irena Szewinska',
#  'Jackson Scholz',
#  'Jesse Owens',
#  'Joseph Nathaniel Jr. Deloach',
#  'Konstantinos Kenteris',
#  'Livio Berruti',
#  'Marie-Jose Perec',
#  'Marjorie Jackson',
#  'Melvin Emery Patton',
#  'Michael Johnson',
#  'Michael Marsh',
#  'Pauline Elaine Davis',
#  'Percy Williams',
#  'Pietro Mennea',
#  'Ralph Craig',
#  'Renate Stecher',
#  'Robert Joseph Morrow',
#  'Robert Kerr',
#  'Shawn Crawford',
#  'Thomas C. Smith',
#  'Usain Bolt',
#  'Valerie Ann Brisco-Hooks',
#  'Valery Borzov',
#  'Veronica Campbell-Brown',
#  'Walter B. John Tewksbury',
#  'Wilma Rudolph'}

# %%
winners_both = {athlete for athlete in winners_100m if athlete in winners_200m}

# %%
winners_both
# Out:
# {'Allyson Felix',
#  'Andrew William Stanfield',
#  'Archie Hahn',
#  'Betty Cuthbert',
#  'BГ¤rbel Eckert-WГ¶ckel',
#  'Carl Lewis',
#  'Eddie Tolan',
#  'Elaine Thompson',
#  'Fanny Blankers-Koen',
#  'Florence Griffith-Joyner',
#  'Gwen Torrence',
#  'Irena Szewinska',
#  'Jackson Scholz',
#  'Jesse Owens',
#  'Marjorie Jackson',
#  'Melvin Emery Patton',
#  'Michael Marsh',
#  'Pauline Elaine Davis',
#  'Percy Williams',
#  'Ralph Craig',
#  'Renate Stecher',
#  'Robert Joseph Morrow',
#  'Usain Bolt',
#  'Valery Borzov',
#  'Veronica Campbell-Brown',
#  'Wilma Rudolph'}

# %%
winners_100m & winners_200m
# Out:
# {'Allyson Felix',
#  'Andrew William Stanfield',
#  'Archie Hahn',
#  'Betty Cuthbert',
#  'BГ¤rbel Eckert-WГ¶ckel',
#  'Carl Lewis',
#  'Eddie Tolan',
#  'Elaine Thompson',
#  'Fanny Blankers-Koen',
#  'Florence Griffith-Joyner',
#  'Gwen Torrence',
#  'Irena Szewinska',
#  'Jackson Scholz',
#  'Jesse Owens',
#  'Marjorie Jackson',
#  'Melvin Emery Patton',
#  'Michael Marsh',
#  'Pauline Elaine Davis',
#  'Percy Williams',
#  'Ralph Craig',
#  'Renate Stecher',
#  'Robert Joseph Morrow',
#  'Usain Bolt',
#  'Valery Borzov',
#  'Veronica Campbell-Brown',
#  'Wilma Rudolph'}

# %%
winners_100m | winners_200m
# Out:
# {'Aleen Bailey',
#  'Aleksandr Aksinin',
#  'Aleksandra Fedoriva',
#  'Alice Regina Brown',
#  'Allan Wells',
#  'Allen Woodring',
#  'Allyson Felix',
#  'Alvin Kraenzlein',
#  'Andrei Prokofiev',
#  'Andrew William Stanfield',
#  'Annegret Richter-Irrgang',
#  'Annelie Ehrhardt',
#  'Annette Joan Rogers',
#  'Archie Hahn',
#  'Ariana Washington',
#  'Armin Hary',
#  'Arthur Russell',
#  'Asafa Powell',
#  'Barbara Ann Ferrell',
#  'Barbara Pearl Jones',
#  'Benita Fitzgerald-Brown',
#  'Bernard Williams iii',
#  'Bernd Cullmann',
#  'Betty Cuthbert',
#  'Beverly Mcdonald',
#  'Bianca Knight',
#  'Brian Lewis',
#  'Brianna Rollins',
#  'Bruny Surin',
#  'BГ¤rbel Eckert-WГ¶ckel',
#  'Calvin Smith',
#  'Carl Lewis',
#  'Carla Bodendorf',
#  'Carlette D. Guidry-White',
#  'Carlton Chambers',
#  'Carmelita Jeter',
#  'Catherine Hardy',
#  'Chandra Danette Cheeseborough',
#  'Chandra Sturrup',
#  'Charles Edward Borah',
#  'Charles Edward Greene',
#  'Charles Paddock',
#  'Christiane Krause',
#  'Chryste Gaines',
#  'Darren Campbell',
#  'David Henry Jacobs',
#  'Dawn Harper',
#  'Debbie Ferguson-Mckenzie',
#  'Dennis Mitchell',
#  'Donald Quarrie',
#  'Donovan Bailey',
#  'Eddie Tolan',
#  'Edith Marie Mcguire',
#  'Edward James Hart',
#  'Elaine Thompson',
#  'Eldice Lewis',
#  'Elizabeth Robinson',
#  'English Gardner',
#  'Esther Jones',
#  'Ethel M. Smith',
#  'Evelyn Ashford',
#  'Evelyn Furtsch',
#  'Evgeniya Polyakova',
#  'Ewa Klobukowska',
#  'Fanny Blankers-Koen',
#  'Fanny Rosenfeld',
#  'Finis Dean Smith',
#  'Florence Griffith-Joyner',
#  'Fluer Northey Mellor-Wenham',
#  'Foy Draper',
#  'Francis Hussey',
#  'Francis Jarvis',
#  'Frank Clifford Wykoff',
#  'Gail Devers',
#  'Gerald A. Tinker',
#  'Gerald Howard Ashworth',
#  'Gerda Johanna Marie Van der kade-Koudijs',
#  'Glenroy Gilbert',
#  'Gwen Torrence',
#  'Halina Herrmann-Gorecka-Richter',
#  'Harold Abrahams',
#  'Harold Norwood Ewell',
#  'Harriett Claiborne Bland',
#  'Harrison Dillard',
#  'Harry Hillman',
#  'Harvey Edward Glance',
#  'Hasely Crawford',
#  'Hector Monroe Dyer',
#  'Heidemarie Rosendahl',
#  'Helen Herring Stephens',
#  'Henry Argue Russell',
#  'Henry Carr',
#  'Henry Maitland Mackintosh',
#  'Inger Miller',
#  'Ingrid Auerswald-Lange',
#  'Ingrid Becker-Mickler',
#  'Ira James Murchison',
#  'Irena Szewinska',
#  'Jackson Scholz',
#  'James F. Quinn',
#  'James Jett',
#  'James Ray Hines',
#  'Janet Theresa Moreau',
#  'Jason Gardener',
#  'Jean Thompson',
#  'Jeanette Bolden',
#  'Jeannette Josephina Maria Witziers-Timmer',
#  'Jeneba Tarmoh',
#  'Jenna Prandini',
#  'Jeremiah Alfred Leconey',
#  'Jesse Owens',
#  'Jevaughn Minzie',
#  'Joanna Hayes',
#  'Johanna Schaller-Klier',
#  'John Wesley Jones',
#  'Jon Drummond',
#  'Joseph Nathaniel Jr. Deloach',
#  'Justin Gatlin',
#  'Kemar Bailey-Cole',
#  'Kenneth Brokenburr',
#  'Konstantinos Kenteris',
#  'Lauryn Williams',
#  'Lawrence J. Black',
#  'Leamon King',
#  'Leroy Burrell',
#  'Lindy Remigino',
#  'Linford Christie',
#  'Liudmila Kondratieva',
#  'Livio Berruti',
#  'Loren Murchison',
#  'Lorenzo Christopher Wright',
#  'Louis Alfred Clarke',
#  'Lucinda Williams',
#  'Ludmila Engquist',
#  'Mae Heriwentha Faggs',
#  'Margaret Johnson Bailes',
#  'Marie-Jose Perec',
#  'Marjorie Jackson',
#  'Mark Lewis-Francis',
#  'Marlies Oelsner-GГ¶hr',
#  'Marlon Devonish',
#  'Martha B. Hudson',
#  'Martin Emmett Toppino',
#  'Martin Lauer',
#  'Mary Louise Carew',
#  'Maurice Greene',
#  'Melvin Emery Patton',
#  'Melvin Jr. Pender',
#  'Michael Frater',
#  'Michael Johnson',
#  'Michael Marsh',
#  'Michelle Finn',
#  'Mildrette Netter',
#  'Millard Frank Jr. Hampton',
#  'Morolake Akinosun',
#  'Morris Kirksey',
#  'Myrtle Alice Cook',
#  'Nesta Carter',
#  'Nickel Ashmeade',
#  'Nikolai Sidorov',
#  'Norma Wilson Crooker-Fleming',
#  'Olga Shishigina',
#  'Otis Paul Drayton',
#  'Paraskevi Voula Patoulidou',
#  'Pauline Elaine Davis',
#  'Percy Williams',
#  'Pietro Mennea',
#  'Ralph Craig',
#  'Ralph Metcalfe',
#  'Reginald Walker',
#  'Renate Stecher',
#  'Richard Vaughn Stebbins',
#  'Robert Allan Kiesel',
#  'Robert Esmie',
#  'Robert Hayes',
#  'Robert Joseph Morrow',
#  'Robert Kerr',
#  'Robert Taylor',
#  'Romy MГјller',
#  'Ronald James Brown',
#  'Ronald Ray Smith',
#  'Sally Pearson',
#  'Samuel Louis Graddy',
#  'Sevatheda Fynes',
#  'Shawn Crawford',
#  'Sheila Echols',
#  'Shelly-Ann Fraser',
#  'Shelly-Ann Fraser-Pryce',
#  'Sherone Simpson',
#  'Shirley Strickland-De La Hunty',
#  'Stanislawa Walasiewicz',
#  'Steven Earl Riddick',
#  'Tanya Lawrence',
#  'Teresa Barbara Wieczorek-Cieply',
#  'Thomas Burke',
#  'Thomas C. Smith',
#  'Tianna Bartoletta',
#  'Tianna Madison',
#  'Tim Montgomery',
#  'Tori Bowie',
#  'Usain Bolt',
#  'Valerie Ann Brisco-Hooks',
#  'Valery Borzov',
#  'Vera Komisova',
#  'Veronica Campbell-Brown',
#  "Victor Henry Augustus D'arcy",
#  'Viktor Bryzgin',
#  'Vitaly Savin',
#  'Vladimir Krylov',
#  'Vladimir Muravyov',
#  'Walter B. John Tewksbury',
#  'Walter Mahlendorf',
#  'Walter Thane Baker',
#  'Wilhelmina Von bremen',
#  'William Applegarth',
#  'Wilma Rudolph',
#  'Wyomia Tyus',
#  'Xenia Stad-De jong',
#  'Yohan Blake',
#  'Yordanka Donkova',
#  'Yulia Gushchina',
#  'Yuliya Chermoshanskaya',
#  'Yuliya Nesterenko'}

# %%
winners_100m - winners_200m
# Out:
# {'Aleen Bailey',
#  'Aleksandr Aksinin',
#  'Aleksandra Fedoriva',
#  'Alice Regina Brown',
#  'Allan Wells',
#  'Andrei Prokofiev',
#  'Annegret Richter-Irrgang',
#  'Annelie Ehrhardt',
#  'Annette Joan Rogers',
#  'Ariana Washington',
#  'Armin Hary',
#  'Asafa Powell',
#  'Barbara Ann Ferrell',
#  'Barbara Pearl Jones',
#  'Benita Fitzgerald-Brown',
#  'Bernard Williams iii',
#  'Bernd Cullmann',
#  'Beverly Mcdonald',
#  'Bianca Knight',
#  'Brian Lewis',
#  'Brianna Rollins',
#  'Bruny Surin',
#  'Calvin Smith',
#  'Carla Bodendorf',
#  'Carlette D. Guidry-White',
#  'Carlton Chambers',
#  'Carmelita Jeter',
#  'Catherine Hardy',
#  'Chandra Danette Cheeseborough',
#  'Chandra Sturrup',
#  'Charles Edward Borah',
#  'Charles Edward Greene',
#  'Charles Paddock',
#  'Christiane Krause',
#  'Chryste Gaines',
#  'Darren Campbell',
#  'David Henry Jacobs',
#  'Dawn Harper',
#  'Debbie Ferguson-Mckenzie',
#  'Dennis Mitchell',
#  'Donovan Bailey',
#  'Edward James Hart',
#  'Eldice Lewis',
#  'Elizabeth Robinson',
#  'English Gardner',
#  'Esther Jones',
#  'Ethel M. Smith',
#  'Evelyn Ashford',
#  'Evelyn Furtsch',
#  'Evgeniya Polyakova',
#  'Ewa Klobukowska',
#  'Fanny Rosenfeld',
#  'Finis Dean Smith',
#  'Fluer Northey Mellor-Wenham',
#  'Foy Draper',
#  'Francis Hussey',
#  'Francis Jarvis',
#  'Frank Clifford Wykoff',
#  'Gail Devers',
#  'Gerald A. Tinker',
#  'Gerald Howard Ashworth',
#  'Gerda Johanna Marie Van der kade-Koudijs',
#  'Glenroy Gilbert',
#  'Halina Herrmann-Gorecka-Richter',
#  'Harold Abrahams',
#  'Harold Norwood Ewell',
#  'Harriett Claiborne Bland',
#  'Harrison Dillard',
#  'Harvey Edward Glance',
#  'Hasely Crawford',
#  'Hector Monroe Dyer',
#  'Heidemarie Rosendahl',
#  'Helen Herring Stephens',
#  'Henry Argue Russell',
#  'Henry Maitland Mackintosh',
#  'Inger Miller',
#  'Ingrid Auerswald-Lange',
#  'Ingrid Becker-Mickler',
#  'Ira James Murchison',
#  'James F. Quinn',
#  'James Jett',
#  'James Ray Hines',
#  'Janet Theresa Moreau',
#  'Jason Gardener',
#  'Jean Thompson',
#  'Jeanette Bolden',
#  'Jeannette Josephina Maria Witziers-Timmer',
#  'Jeneba Tarmoh',
#  'Jenna Prandini',
#  'Jeremiah Alfred Leconey',
#  'Jevaughn Minzie',
#  'Joanna Hayes',
#  'Johanna Schaller-Klier',
#  'John Wesley Jones',
#  'Jon Drummond',
#  'Justin Gatlin',
#  'Kemar Bailey-Cole',
#  'Kenneth Brokenburr',
#  'Lauryn Williams',
#  'Lawrence J. Black',
#  'Leamon King',
#  'Leroy Burrell',
#  'Lindy Remigino',
#  'Linford Christie',
#  'Liudmila Kondratieva',
#  'Loren Murchison',
#  'Lorenzo Christopher Wright',
#  'Louis Alfred Clarke',
#  'Lucinda Williams',
#  'Ludmila Engquist',
#  'Mae Heriwentha Faggs',
#  'Margaret Johnson Bailes',
#  'Mark Lewis-Francis',
#  'Marlies Oelsner-GГ¶hr',
#  'Marlon Devonish',
#  'Martha B. Hudson',
#  'Martin Emmett Toppino',
#  'Martin Lauer',
#  'Mary Louise Carew',
#  'Maurice Greene',
#  'Melvin Jr. Pender',
#  'Michael Frater',
#  'Michelle Finn',
#  'Mildrette Netter',
#  'Millard Frank Jr. Hampton',
#  'Morolake Akinosun',
#  'Morris Kirksey',
#  'Myrtle Alice Cook',
#  'Nesta Carter',
#  'Nickel Ashmeade',
#  'Nikolai Sidorov',
#  'Norma Wilson Crooker-Fleming',
#  'Olga Shishigina',
#  'Otis Paul Drayton',
#  'Paraskevi Voula Patoulidou',
#  'Ralph Metcalfe',
#  'Reginald Walker',
#  'Richard Vaughn Stebbins',
#  'Robert Allan Kiesel',
#  'Robert Esmie',
#  'Robert Hayes',
#  'Robert Taylor',
#  'Romy MГјller',
#  'Ronald James Brown',
#  'Ronald Ray Smith',
#  'Sally Pearson',
#  'Samuel Louis Graddy',
#  'Sevatheda Fynes',
#  'Sheila Echols',
#  'Shelly-Ann Fraser',
#  'Shelly-Ann Fraser-Pryce',
#  'Sherone Simpson',
#  'Shirley Strickland-De La Hunty',
#  'Stanislawa Walasiewicz',
#  'Steven Earl Riddick',
#  'Tanya Lawrence',
#  'Teresa Barbara Wieczorek-Cieply',
#  'Thomas Burke',
#  'Tianna Bartoletta',
#  'Tianna Madison',
#  'Tim Montgomery',
#  'Tori Bowie',
#  'Vera Komisova',
#  "Victor Henry Augustus D'arcy",
#  'Viktor Bryzgin',
#  'Vitaly Savin',
#  'Vladimir Krylov',
#  'Vladimir Muravyov',
#  'Walter Mahlendorf',
#  'Walter Thane Baker',
#  'Wilhelmina Von bremen',
#  'William Applegarth',
#  'Wyomia Tyus',
#  'Xenia Stad-De jong',
#  'Yohan Blake',
#  'Yordanka Donkova',
#  'Yulia Gushchina',
#  'Yuliya Chermoshanskaya',
#  'Yuliya Nesterenko'}

# %%
for medal in medals:
    if medal.event == 'long jump':
        print('In %s, %s won for %s.' % (medal.year, medal.athlete, medal.team))
# Out:
# In 2016, Tianna Bartoletta won for USA.
# In 2016, Jeff Henderson won for USA.

# %%
for medal in medals:
    if medal.event.startswith('long jump'):
        print('In {year}, {athlete} won for {team}.'.format(year=medal.year, athlete=medal.athlete, team=medal.team))
# Out:
# In 1896, Ellery Clark won for USA.
# In 1900, Alvin Kraenzlein won for USA.
# In 1900, Ray Ewry won for USA.
# In 1904, Meyer Prinstein won for USA.
# In 1904, Ray Ewry won for USA.
# In 1908, Francis C. Irons won for USA.
# In 1908, Ray Ewry won for USA.
# In 1912, Albert Lovejoy Gutterson won for USA.
# In 1912, Konstantinos Tsiclitiras won for GRE.
# In 1920, R. William E. Petersson won for SWE.
# In 1924, William De Hart Hubbard won for USA.
# In 1928, Edward Barton Hamm won for USA.
# In 1932, Edward Lansing Gordon won for USA.
# In 1936, Jesse Owens won for USA.
# In 1948, William Samuel Steele won for USA.
# In 1948, Olga Gyarmati won for HUN.
# In 1952, Jerome Cousins Biffle won for USA.
# In 1952, Yvette Winefred Williams won for NZL.
# In 1956, Gregory Curtis Bell won for USA.
# In 1956, Elzbieta Dunska-Krzesinska won for POL.
# In 1960, Ralph Harold Boston won for USA.
# In 1960, Vera Kolashnikova-Krepkina won for URS.
# In 1964, Lynn Davies won for GBR.
# In 1964, Mary Denise Bignal-Rand won for GBR.
# In 1968, Bob Beamon won for USA.
# In 1968, Viorica Viscopoleanu won for ROU.
# In 1972, Randel Luvelle Williams won for USA.
# In 1972, Heidemarie Rosendahl won for FRG.
# In 1976, Arnie Robinson won for USA.
# In 1976, Angela Voigt won for GDR.
# In 1980, Lutz Dombrowski won for GDR.
# In 1980, Tatiana Kolpakova won for URS.
# In 1984, Carl Lewis won for USA.
# In 1984, Anisoara Cusmir-Stanciu won for ROU.
# In 1988, Carl Lewis won for USA.
# In 1988, Jackie Joyner-Kersee won for USA.
# In 1992, Carl Lewis won for USA.
# In 1992, Heike Drechsler won for GER.
# In 1996, Carl Lewis won for USA.
# In 1996, Chioma Ajunwa won for NGR.
# In 2000, Ivan Pedroso won for CUB.
# In 2000, Heike Drechsler won for GER.
# In 2004, Dwight Phillips won for USA.
# In 2004, Tatyana Lebedeva won for RUS.
# In 2008, Irving Jahir Saladino aranda won for PAN.
# In 2008, Maurren Higa Maggi won for BRA.
# In 2012, Greg Rutherford won for GBR.
# In 2012, Brittney Reese won for USA.
# In 2016, Tianna Bartoletta won for USA.
# In 2016, Jeff Henderson won for USA.

# %%
def findmedal(year=None, team=None, event=None):
    filtered = medals
    
    if year is not None:
        filtered = [medal for medal in filtered if medal.year == year]
    if team is not None:
        filtered = [medal for medal in filtered if medal.team == team]
    if event is not None:
        filtered = [medal for medal in filtered if medal.event == event]
    
    return filtered

# %%
findmedal(year='1896', team ='USA')
# Out:
# [medal(year='1896', athlete='Thomas Burke', team='USA', event='100m men'),
#  medal(year='1896', athlete='Thomas Curtis', team='USA', event='110m hurdles men'),
#  medal(year='1896', athlete='Thomas Burke', team='USA', event='400m men'),
#  medal(year='1896', athlete='Robert Garrett', team='USA', event='discus throw men'),
#  medal(year='1896', athlete='Ellery Clark', team='USA', event='high jump men'),
#  medal(year='1896', athlete='Ellery Clark', team='USA', event='long jump men'),
#  medal(year='1896', athlete='William Welles Hoyt', team='USA', event='pole vault men'),
#  medal(year='1896', athlete='Robert Garrett', team='USA', event='shot put men'),
#  medal(year='1896', athlete='James Connolly', team='USA', event='triple jump men')]

# %%
def findmedal(**kwargs):
    return[medal for medal in medals
          if all(getattr(medal, key) == value for key, value in kwargs.items())]

# %%
findmedal(year='1896', team ='USA')
# Out:
# [medal(year='1896', athlete='Thomas Burke', team='USA', event='100m men'),
#  medal(year='1896', athlete='Thomas Curtis', team='USA', event='110m hurdles men'),
#  medal(year='1896', athlete='Thomas Burke', team='USA', event='400m men'),
#  medal(year='1896', athlete='Robert Garrett', team='USA', event='discus throw men'),
#  medal(year='1896', athlete='Ellery Clark', team='USA', event='high jump men'),
#  medal(year='1896', athlete='Ellery Clark', team='USA', event='long jump men'),
#  medal(year='1896', athlete='William Welles Hoyt', team='USA', event='pole vault men'),
#  medal(year='1896', athlete='Robert Garrett', team='USA', event='shot put men'),
#  medal(year='1896', athlete='James Connolly', team='USA', event='triple jump men')]

# %%
findmedal(athlete='James Connolly')
# Out:
# [medal(year='1896', athlete='James Connolly', team='USA', event='triple jump men')]
